# %% [markdown]
# # Mcstas for pol_Bender

# %% [markdown]
# * Problems:
# > 1. The difference between MeanPolLambda_monitor and PolLambda_monitor?
# > 2. Could not see 3D view of the instrument (black black window)
# > 3. How to get the real flux? Now too low
# > 4. Parallel computing?
# > 5. How to print out the calculated parameters e.g. Bender length while running for checking
# > 6. The monitors used are right?
#
# * Bender vs pol_Bender
# > 1. Cylindrical (but with _h_ and _w_) - Rectangular
# > 2. No Rotation - Need Rotation after it

# %%
# mcrun Pol_Bender.instr -N11 BENDERRADIUS=5,15 BENDERLENGTH=0.154
from matplotlib.pyplot import cm
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib ipympl
plt.style.use('seaborn')
from matplotlib import rcParams
rcParams['axes.titley'] = 1.1
plt.rcParams['lines.linewidth'] = 1

from latexify import latexify
latexify()

# %%
(1-0.75)/(0.109-0.0216)
0.06/333

# %%
plt.close('all')

# %%
print(60/0.13)
print(0.05**2/8/0.00010)
0.00013
0.00001
1325*1.16
1414.62*0.95
0.75/1.75

# %%
Lc = np.linspace(1,2, num=6, endpoint=True) # critical lambda
Ac = Lc*(1.73*3.6)*1e-3 # critical angle in rad
Rs = 2*(0.06/461)/Ac**2*1e6 # radius in meter
Ls = Ac*(2*Rs) # length in m
print(Lc, '\n', Ac,'\n', Rs,'\n', Ls)

# %%
#make_sub_plot(load_results(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_ao_20210120_112315_compare_1')) # new 
#make_sub_plot(load_results(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20210120_113052_compare_2')) # new 
data = load_results(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_divSClam_20210128_123937')
make_sub_plot(data)
plt.figure()
x = np.linspace(0.5,9.5, num=51, endpoint=True)
y = np.linspace(-3,3, num=100, endpoint=True)
plt.pcolor(x,y, data[1].Intensity)
plt.show()

plt.figure()
for i in range(0,51,10):
    plt.errorbar(y, data[1].Intensity[:,i],data[1].Error[:,i])
plt.show()

# %% [markdown]
# ## Compare the component with Gd and without Gd

# %%
data_Gd = load_results(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20201215_111723_Gd')
make_sub_plot(data_Gd)
data_noGd = load_results(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20201215_111912_noGd')
make_sub_plot(data_noGd)

# %%
data_noGd = load_results(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20210115_222250/0')
make_sub_plot(data_noGd)

# %%
# Compare X-divergence
fig2, ax = plt.subplots() 
idx_div = 5
xaxis = np.linspace(data_Gd[idx_div].metadata.limits[0], data_Gd[idx_div].metadata.limits[1],data_Gd[idx_div].metadata.dimension, endpoint=True)

ax.errorbar(x =  xaxis, 
            y =  data_Gd[idx_div].Intensity, 
            yerr=data_Gd[idx_div].Error, label='with Gd' )
ax.errorbar(x =  xaxis, 
            y =  data_noGd[idx_div].Intensity, 
            yerr=data_noGd[idx_div].Error, label='without Gd' )

ax.set_xlabel('X-divergence (deg)')
ax.set_xlim([-1.5,1.5]) #ax2.set_xlim([-0.5,2])
ax.set_title('Divergence of reflected spin up after bender')
ax.legend(title='H_div')
plt.tight_layout()
plt.show()

# %%
data = load_results(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20201215_000003\1')
#data = load_results(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simple_20201201_171251')
make_sub_plot(data)

# %% [markdown]
# # 10%, div source, Gd absorption

# %%
#make_sub_plot(load_results(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20210121_214949_divS_1p1long_Gd_absorb\0'))
#make_sub_plot(load_results(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20210121_214949_divS_1p1long_Gd_absorb\9'))
#make_sub_plot(load_results(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20210123_150556\9'))
make_sub_plot(load_results(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_divSClam_20210128_155940/0'))

# %%
path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div2/5'
make_sub_plot(load_results(path))

# %%
plt.close('all')
path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div1/'
path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div2/'
#path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div1p0_2p0/'
#path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div1p7_2p8/'
*figsaxs, color = load_plot_scan(path, start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=4, idx_I_before=13, idx_I_after=12, 
                   idx_div=None,idx_div_col=None,col_div=None, longer=longer)
figs, axs = figsaxs[:int(len(figsaxs)/2)], figsaxs[int(len(figsaxs)/2):]
figs[0].set_size_inches(5, 4, forward=True)
figs[1].set_size_inches(5, 4, forward=True)
axs[1].set_ylim([0.,0.5])

# %% [markdown]
# ## Calculate absorbtion

# %%
# Scan related parameters
longer = 1.1
Ls = np.linspace(0.03,0.13, num=11, endpoint=True) # bender length
Rs = (Ls**2/8/(0.06/461))/longer # bender radius
Ac = Ls/(2*Rs) # critical angle
Ac = np.sqrt(2*0.06/461/Rs)# use this one for calculating Lmabda_c if bender is longer than the exact value for avoiding direct view
#print(Ac, Ac2)
Lc = Ac/(1.73*3.6)*1e3 # critical lambda
Angle = -Ls/Rs*180/3.1415926 # bender arc angle

# calculate analytical results with different critical lambda
lams = np.linspace(0.1,10, num=100, endpoint=True)
def trans_ref(lam, lam_c):
    # From the Excel file of Peter Boeni: 2/3*(A19/B19)^2,  2/3*(A19/B19)^2 * ( 1 - ( 1-(B19/A19)^2  )^(3/2) )
    return 0.5*np.where(lam<=lam_c, 2/3*(lam/lam_c)**2,  2/3*(lam/lam_c)**2 * ( 1 - ( 1-(lam_c/lam)**2  )**(3/2) )) # 0.5 for polarized
    
def trans_ref_absorb(lam, lam_c, m, L, R, d=0.000130, div=None):
    Si_i, Si_a = 0.2, 0.215
    Si_cross_i = 2.33 / 28.09 * Si_i* 6.022 * 10
    Si_cross_a_v = 2.33 / 28.09 * Si_a * 6.022 * 10 * 2200.0
    
    v = 3956/lam
    Si_cross_tot=Si_cross_i + Si_cross_a_v / v;
    
    gamma = m * 1.73 * lam /1000
    l1, l2 =  L/R/(2*gamma) * d/np.sin(gamma), L/np.cos(gamma)
    
    a1, a2 = np.exp(-Si_cross_tot*l1), np.exp(-Si_cross_tot*l2)
    
    if div != None:
        r = np.where(div>gamma, gamma/div, 1)
        return 0.5*np.where(lam<=lam_c,  r* 2/3*(lam/lam_c)**2 * a1 , r * 2/3*(lam/lam_c)**2 * ( 1 - ( 1-(lam_c/lam)**2  )**(3/2) ) * a2  ) # 0.5 for polarized 
    else:
        return 0.5*np.where(lam<=lam_c, 2/3*(lam/lam_c)**2 * a1 ,  2/3*(lam/lam_c)**2 * ( 1 - ( 1-(lam_c/lam)**2  )**(3/2) ) * a2  ) # 0.5 for polarized
    
def trans_ref_orig(lam, m=3.6, d=0.00013, R=1, div_h=2, div_v=2):
    h = 1
    div_h, div_v = div_h/180*3.14, div_v/180*3.14
    
    gamma_c = m * 1.73 * lam /1000
    
    def inte(phi0, x):
        return -R/3*(phi0**2-2*x/R)**1.5
    
    gamma_c_div = np.where(gamma_c<=div_h, gamma_c, div_h)
    
    ulim = np.where(gamma_c_div**2*R/2 <= d, gamma_c_div**2*R/2, d)
    theta = np.where(gamma_c<=div_v, gamma_c, div_v)
    
    #return 4*h*theta*(inte(gamma_c_div, ulim)-inte(gamma_c_div, 0))/(4*h*d*div_h*div_v)
    print(inte(gamma_c_div, ulim), inte(gamma_c_div, 0))
    return 4*h*(inte(gamma_c_div, ulim)-inte(gamma_c_div, 0))/(4*h*d*div_h)
    #print(gamma_star, gamma_c, gamma_star>=gamma_c)
    #return np.where(gamma_star>=gamma_c, h*R*gamma_c**4*1.333/(4*h*d*div_h*div_v),  h*R*gamma_c**4*1.333*(1-(1-2*d/R/gamma_c**2)**1.5) / (4*h*d*div_h*div_v))
    
def trans_ref_orig(lam, m=3.6, d=0.00013, R=1, div_h=2, div_v=2):
    h = 1
    div_h, div_v = div_h/180*3.14, div_v/180*3.14
    
    gamma_c = m * 1.73 * lam /1000
    
 
    theta_c_div = np.where(gamma_c<=div_h, gamma_c, div_h)
    
    theta = np.where(gamma_c<=div_v, gamma_c, div_v)
    
    def inte(theta_c_div, gamma_c):
        return theta_c_div*gamma_c**4 + 0.2*theta_c_div**5 - 0.6667*theta_c_div**3*gamma_c**2
    
    return 4*h*inte(theta_c_div, gamma_c)/(4*h*d*div_h)

# %%
mon = np.array([0.035, 0.015, 0.0238, 1])*425000
mon_sum = mon.sum()
print(mon, mon_sum)
print(3367.12+219, 28402.6+31233.12)
13400-4500-1408-1300
13400*0.37

# %%
plt.close('all')
plt.figure(figsize=(5,4))
for i in range(11):
    plt.plot(lams, trans_ref_orig(lams, m=3.6, d=0.00013, R=Rs[i], div_h=0.1, div_v=1), color=color[i], ls='dotted')
plt.show()

# %%
plt.close('all')
path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_divSClam_20210128_155940/'
*figsaxs, color = load_plot_scan(path, start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=6, idx_I_before=4, idx_I_after=8, 
                   idx_div=None,idx_div_col=None,col_div=None, longer=longer)
figs, axs = figsaxs[:int(len(figsaxs)/2)], figsaxs[int(len(figsaxs)/2):]
figs[0].set_size_inches(5, 4, forward=True)
figs[1].set_size_inches(5, 4, forward=True)

for i in range(11):
    #plot vertical lines at the critical lambda
    axs[1].axvline(Lc[i], color=color[i], ls='--')
    #plot analytical results
    #axs[1].plot(lams, trans_ref(lams,Lc[i])/2, color=color[i], ls='dotted')
    axs[1].plot(lams, trans_ref_absorb(lams,Lc[i], 3.6, Ls[i], Rs[i])/2, color=color[i], ls='dotted')

# %%
path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div1p0_2p7/'
path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div1p7_2p8/'
path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div1p0_2p0/'
#path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div1p4_2p7/'
#path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div1p4_3p0/'
#path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div2p2_2p7/'
*figsaxs, color = load_plot_scan(path, start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=4, idx_I_before=1, idx_I_after=6, 
                   idx_div=None,idx_div_col=None,col_div=None, longer=longer)
figs, axs = figsaxs[:int(len(figsaxs)/2)], figsaxs[int(len(figsaxs)/2):]
figs[0].set_size_inches(5, 4, forward=True)
figs[1].set_size_inches(5, 4, forward=True)
axs[0].set_ylim([-0.05,1.05])

for i in range(11):
    #plot vertical lines at the critical lambda
    axs[1].axvline(Lc[i], color=color[i], ls='--')
    #plot analytical results
    axs[1].plot(lams, trans_ref(lams,Lc[i]), color=color[i], ls='dotted')

# %%
plt.close('all')
path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div0p1_absorb/'
path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div1p7_2p8_absorb/'
*figsaxs, color = load_plot_scan(path, start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=4, idx_I_before=1, idx_I_after=6, idx_I_sample=[12,13],
                   idx_div=None,idx_div_col=None,col_div=None, longer=longer)
figs, axs = figsaxs[:int(len(figsaxs)/2)], figsaxs[int(len(figsaxs)/2):]
figs[0].set_size_inches(5, 4, forward=True)
figs[1].set_size_inches(5, 4, forward=True)
axs[0].set_ylim([-0.05,1.05])

for i in range(11):
    #plot vertical lines at the critical lambda
    #axs[1].axvline(Lc[i], color=color[i], ls='--')
    #plot analytical results
    #axs[1].plot(lams, trans_ref(lams,Lc[i]), color=color[i], ls='dotted')
    axs[1].plot(lams, trans_ref_absorb(lams,Lc[i], 3.6, Ls[i], Rs[i], div=None), color=color[i])
    
plt.figure(figsize=(5,4))
for i in range(11):
    plt.plot(lams, trans_ref_absorb(lams,Lc[i], 3.6, Ls[i], Rs[i]), color=color[i])
    
plt.xlabel('Wavelength ($\mathrm{\AA}$)')
plt.ylabel('Intensity')
plt.show()

# %%
path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div0p1_absorb/'
*figsaxs, color = load_plot_scan(path, start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=4, idx_I_before=1, idx_I_after=6, 
                   idx_div=None,idx_div_col=None,col_div=None, longer=longer)
figs, axs = figsaxs[:int(len(figsaxs)/2)], figsaxs[int(len(figsaxs)/2):]
figs[0].set_size_inches(5, 4, forward=True)
figs[1].set_size_inches(5, 4, forward=True)
axs[0].set_ylim([-0.05,1.05])

for i in range(11):
    #plot vertical lines at the critical lambda
    #axs[1].axvline(Lc[i], color=color[i], ls='--')
    axs[1].plot(lams, trans_ref_absorb(lams,Lc[i], 3.6, Ls[i], Rs[i]), color=color[i])
    
plt.figure(figsize=(5,4))
for i in range(11):
    plt.plot(lams, trans_ref_absorb(lams,Lc[i], 3.6, Ls[i], Rs[i]), color=color[i])
    
plt.xlabel('Wavelength ($\mathrm{\AA}$)')
plt.ylabel('Intensity')
plt.show()

# %%
   
path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div0p1/'
*figsaxs, color = load_plot_scan(path, start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=4, idx_I_before=1, idx_I_after=6, 
                   idx_div=None,idx_div_col=None,col_div=None, longer=longer)
figs, axs = figsaxs[:int(len(figsaxs)/2)], figsaxs[int(len(figsaxs)/2):]
figs[0].set_size_inches(5, 4, forward=True)
figs[1].set_size_inches(5, 4, forward=True)
axs[0].set_ylim([-0.05,1.05])

for i in range(11):
    #plot vertical lines at the critical lambda
    axs[1].axvline(Lc[i], color=color[i], ls='--')
    #plot analytical results
    axs[1].plot(lams, trans_ref(lams,Lc[i]), color=color[i], ls='dotted')

path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div1/'
*figsaxs, color = load_plot_scan(path, start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=4, idx_I_before=1, idx_I_after=6, 
                   idx_div=None,idx_div_col=None,col_div=None, longer=longer)
figs, axs = figsaxs[:int(len(figsaxs)/2)], figsaxs[int(len(figsaxs)/2):]
figs[0].set_size_inches(5, 4, forward=True)
figs[1].set_size_inches(5, 4, forward=True)
axs[0].set_ylim([-0.05,1.05])

for i in range(11):
    #plot vertical lines at the critical lambda
    axs[1].axvline(Lc[i], color=color[i], ls='--')
    #plot analytical results
    axs[1].plot(lams, trans_ref(lams,Lc[i]), color=color[i], ls='dotted')
    
path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div2/'
*figsaxs, color = load_plot_scan(path, start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=4, idx_I_before=1, idx_I_after=6, 
                   idx_div=None,idx_div_col=None,col_div=None, longer=longer)
figs, axs = figsaxs[:int(len(figsaxs)/2)], figsaxs[int(len(figsaxs)/2):]
figs[0].set_size_inches(5, 4, forward=True)
figs[1].set_size_inches(5, 4, forward=True)
axs[0].set_ylim([-0.05,1.05])

for i in range(11):
    #plot vertical lines at the critical lambda
    axs[1].axvline(Lc[i], color=color[i], ls='--')
    #plot analytical results
    axs[1].plot(lams, trans_ref(lams,Lc[i], div=2.0), color=color[i], ls='dotted')
    
path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div2_3/'
*figsaxs, color = load_plot_scan(path, start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=4, idx_I_before=1, idx_I_after=6, 
                   idx_div=None,idx_div_col=None,col_div=None, longer=longer)
figs, axs = figsaxs[:int(len(figsaxs)/2)], figsaxs[int(len(figsaxs)/2):]
figs[0].set_size_inches(5, 4, forward=True)
figs[1].set_size_inches(5, 4, forward=True)
axs[0].set_ylim([-0.05,1.05])

for i in range(11):
    #plot vertical lines at the critical lambda
    axs[1].axvline(Lc[i], color=color[i], ls='--')
    #plot analytical results
    axs[1].plot(lams, trans_ref(lams,Lc[i]), color=color[i], ls='dotted')

# %%
plt.close('all')
path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20210121_230626_divS_1p1long_Gd_noAbsorb/'
*figsaxs, color = load_plot_scan(path, start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=3, idx_I_before=1, idx_I_after=5, 
                   idx_div=None,idx_div_col=None,col_div=None,longer=1.1)
figs, axs = figsaxs[:int(len(figsaxs)/2)], figsaxs[int(len(figsaxs)/2):]
figs[0].set_size_inches(5, 4, forward=True)
figs[1].set_size_inches(5, 4, forward=True)

for i in range(11):
    #plot vertical lines at the critical lambda
    axs[1].axvline(Lc[i], color=color[i], ls='--')
    #plot analytical results
    axs[1].plot(lams, trans_ref(lams,Lc[i]), color=color[i], ls='dotted')

path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20210121_214949_divS_1p1long_Gd_absorb/'
*figsaxs, color = load_plot_scan(path, start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=3, idx_I_before=1, idx_I_after=5, 
                   idx_div=None,idx_div_col=None,col_div=None,longer=1.1)
figs, axs = figsaxs[:int(len(figsaxs)/2)], figsaxs[int(len(figsaxs)/2):]
figs[0].set_size_inches(5, 4, forward=True)
figs[1].set_size_inches(5, 4, forward=True)
for i in range(11):
    #plot vertical lines at the critical lambda
    axs[1].axvline(Lc[i], color=color[i], ls='--')
    #plot analytical results
    axs[1].plot(lams, trans_ref(lams,Lc[i]), color=color[i], ls='dotted')
    
path = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20210123_150556_divS_1p1long_Gd_noAbsorb_0p1divS/'
*figsaxs, color = load_plot_scan(path, start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=3, idx_I_before=1, idx_I_after=5, 
                   idx_div=None,idx_div_col=None,col_div=None,longer=1.1)
figs, axs = figsaxs[:int(len(figsaxs)/2)], figsaxs[int(len(figsaxs)/2):]
figs[0].set_size_inches(5, 4, forward=True)
figs[1].set_size_inches(5, 4, forward=True)
for i in range(11):
    #plot vertical lines at the critical lambda
    axs[1].axvline(Lc[i], color=color[i], ls='--')
    #plot analytical results
    axs[1].plot(lams, trans_ref(lams,Lc[i]), color=color[i], ls='dotted')

# %%
plt.close('all')

# %% [markdown]
# # with Div_monitor

# %%
data = load_results(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sc_guide_mono_20201222_130841')
#data = load_results(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20201218_102003\10')
#data = load_results(r'D:\5_Instrument\Mira_Bender\Pol_Bender_calc_R_col_div_m=10_a=0/1')
make_sub_plot(data)

# %%
print(data[4].Intensity[:,26])

# %%
fig, ax = plt.subplots()

ax.errorbar(x = np.linspace(-3.5,2.0, 100,endpoint=True),
            y = data[0].Intensity[:,25]/30, 
            yerr=data[0].Error[:,25]/30, label='Source/30')

ax.errorbar(x = np.linspace(-3.5,2.0, 100,endpoint=True),
            y = data[3].Intensity[:,25]/7, 
            yerr=data[3].Error[:,25]/7, label='After Guide/7')

ax.errorbar(x = np.linspace(-3.5,2.0, 100,endpoint=True),
            y = data[4].Intensity[:,25], 
            yerr=data[4].Error[:,25], label='After mono')
    
ax.errorbar(x = np.linspace(-3.5,2.0, 100,endpoint=True),
            y = data[6].Intensity[:,25], 
            yerr=data[6].Error[:,25], label='After Bender')

ax.set_xlabel('H_div (degree)')
ax.set_ylabel('Intensity')
plt.legend()

# %%
fig1, ax1 = my_make_plot(data[9]/data[5])

print(data[9],data[5])

# %%
# Scan related parameters
Ls = np.linspace(0.03,0.13, num=11, endpoint=True) # bender length
Rs = (Ls**2/8/(0.06/461)) # bender radius
Ac = Ls/(2*Rs) # critical angle
Lc = Ac/(1.73*3.6)*1e3 # critical lambda
Angle = -Ls/Rs*180/3.1415926 # bender arc angle

# calculate analytical results with different critical lambda
lams = np.linspace(0.1,10, num=100, endpoint=True)
def trans_ref(lam, lam_c):
    # From the Excel file of Peter Boeni: 2/3*(A19/B19)^2,  2/3*(A19/B19)^2 * ( 1 - ( 1-(B19/A19)^2  )^(3/2) )
    return 0.5*np.where(lam<=lam_c, 2/3*(lam/lam_c)**2,  2/3*(lam/lam_c)**2 * ( 1 - ( 1-(lam_c/lam)**2  )**(3/2) )) # 0.5 for polarized

# %%
np.tan(0.5/180.*3.14)*1*2
0.3/0.4
44/56
(6.8-1.2) / (6.8+1.2)

# %%
#make_sub_plot(load_results(r'D:\5_Instrument\Mira_Bender\Pol_Bender_calc_R_col_div_m=10_a=0/0'))
              
#make_sub_plot(load_results(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20201218_102003_Gd/0'))

#make_sub_plot(load_results(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20201218_100619_noGd_withCol/0'))

make_sub_plot(load_results(r'D:\5_Instrument\Mira_Bender\Pol_Bender_calc_R_col_div_20201116_173617/0'))

make_sub_plot(load_results(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20210115_222250_Gd_L10pecentMore/0')) # new 
make_sub_plot(load_results(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20201218_102003_Gd/0')) # old

make_sub_plot(load_results(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20210117_160710_noGd_trans_withCol\0'))

# %%
plt.close("all")

# Using pol_bender
# *axs, color = load_plot_scan(r'D:\5_Instrument\Mira_Bender\Pol_Bender_calc_R_col_div_20201116_173617/', 
#               start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=6, idx_I_before=2, idx_I_after=5,idx_div_col=None,col_div=100)
# *axs, color = load_plot_scan(r'D:\5_Instrument\Mira_Bender\Pol_Bender_calc_R_col_div_m=10_a=0/', 
#                start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=6, idx_I_before=2, idx_I_after=5,idx_div_col=[7,8],col_div=100)

# Using AO bender
# *axs, color = load_plot_scan(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20210115_222250_Gd_L10pecentMore/', 
#              start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=13, idx_I_before=1, idx_I_after=3, idx_div=6, idx_div_col=[6,10],col_div='Bender arc')

*axs, color = load_plot_scan(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20201218_102003_Gd/', 
             start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=12, idx_I_before=1, idx_I_after=3, idx_div=5, idx_div_col=[5,10],col_div='Bender arc')

# *axs, color = load_plot_scan(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20201218_100619_noGd_withCol/', 
#              start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=12, idx_I_before=1, idx_I_after=8, idx_div=5, idx_div_col=[5,10],col_div='Bender arc')

# 
# *axs, color = load_plot_scan(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20210117_220605_noGd_trans_withCol_coldivC0p25/', 
#              start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=13, idx_I_before=1, idx_I_after=9, idx_div=6, idx_div_col=[6,11],col_div='Bender arc')

# *axs, color = load_plot_scan(r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20201222_105801_noGd_trans_withCol_coldivC1/', 
#              start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=12, idx_I_before=1, idx_I_after=8, idx_div=5, idx_div_col=[5,10],col_div='Bender arc')


for i in range(11):
    #plot vertical lines at the critical lambda
    axs[1].axvline(Lc[i], color=color[i], ls='--')
    #plot analytical results
    axs[1].plot(lams, trans_ref(lams,Lc[i]), color=color[i], ls='dotted')

axs[1].text(0.2,0.32, r'Vertical lines: critical $\lambda_c=\frac{\gamma_c}{1.73 m\,\mathsf{(mrad/\AA)}}$'+ \
            '\ncritical angle: '+r'$\gamma_c=\frac{L}{2R}$'+'\n'+ r'$m=3.6,\,\alpha=2.6$', transform=axs[1].transAxes,size=14)
axs[1].set_xlim([0.5,7])

#axs[2].text(-3,0.32*1e-6, 'Bender arc angle', transform=axs[2].transData,  horizontalalignment='left')
#for idx, a in enumerate(Angle):
#    axs[2].text(a, 0.32*1e-6*(10-idx)/10, ('%1.3f' % a) + r'$^\circ$', transform=axs[2].transData,  horizontalalignment='center')
#    axs[3].text(a, 0.35*1e-6*(10-idx)/10, ('%1.3f' % a) + r'$^\circ$', transform=axs[3].transData,  horizontalalignment='center')

# %%
0.00013/0.05*180/3.14

# %%
# Plot I-lambda of two scans in two subpolots with shared Y
def load_plot_scan_inAx(ax, wch, path, start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=6, idx_I_before=2, idx_I_after=5):
    Scan=[]
    param = np.linspace(start_end_nb[0], start_end_nb[1], start_end_nb[2], endpoint=True) # Bender radius
    color = cm.get_cmap('jet')((param-param[0])/(param[-1]-param[0]))
    nS = 461
    for i in range(start_end_nb[2]):
        Scan.append(load_results(path+str(i)+'/'))

    for i in range(len(param)): 
        if wch == 0: # plot pol-lambda
            ax.errorbar(Scan[i][idx_pol].xaxis, Scan[i][idx_pol].Intensity, yerr=0*Scan[i][idx_pol].Error, c=color[i], 
                                 label='L=%1.3f'%param[i]+' m,'  +  ' R$_{calc}=$%1.1f' % (param[i]**2/8/(0.06/nS)) )
        if wch == 1: # plot I vs Lambda
            ax.errorbar(x =  Scan[i][idx_I_after].xaxis, 
                        y =  Scan[i][idx_I_after].Intensity/Scan[i][idx_I_before].Intensity/0.5, 
                        yerr=Scan[i][idx_I_after].Error    /Scan[i][idx_I_before].Intensity/0.5,
                        c=color[i], 
                        label='L=%1.3f'%param[i]+' m,'  +  r' R$_{calc}=$%1.1f' % (param[i]**2/8/(0.06/nS)))
    plt.legend(title='nSlits=%d'%nS)
    

# fig, axs = plt.subplots(nrows=1, ncols=2, sharey=True)
# load_plot_scan_inAx(axs[0], r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20201218_102003_Gd/', 
#              start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=12, idx_I_before=1, idx_I_after=8)

# load_plot_scan_inAx(axs[1], r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20201218_102003_Gd/', 
#              start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=12, idx_I_before=1, idx_I_after=7)

# for i in range(11):
#     #plot vertical lines at the critical lambda
#     axs[0].axvline(Lc[i], color=color[i], ls='--')
#     axs[1].axvline(Lc[i], color=color[i], ls='--')
#     #plot analytical results
#     axs[0].plot(lams, trans_ref(lams,Lc[i]), color=color[i], ls='dotted')
#     axs[1].plot(lams, trans_ref(lams,Lc[i]), color=color[i], ls='dotted')

# axs[0].set_xlabel('Wavelength'+r' ($\mathrm{\AA^{-1}}$)')
# axs[1].set_xlabel('Wavelength'+r' ($\mathrm{\AA^{-1}}$)')
# axs[0].set_ylabel('Intensity')

fig, axs = plt.subplots(nrows=1, ncols=2, sharey=True)
load_plot_scan_inAx(axs[0],0, r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20201222_105801_noGd_trans_withCol_coldivC1/', 
             start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=12, idx_I_before=1, idx_I_after=8)

load_plot_scan_inAx(axs[1], 0, r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20210117_220605_noGd_trans_withCol_coldivC0p25/', 
             start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=13, idx_I_before=1, idx_I_after=9)

axs[0].set_xlabel('Wavelength'+r' ($\mathrm{\AA^{-1}}$)')
axs[1].set_xlabel('Wavelength'+r' ($\mathrm{\AA^{-1}}$)')
axs[0].set_ylabel('Polarization')

fig, axs = plt.subplots(nrows=1, ncols=2, sharey=True)
load_plot_scan_inAx(axs[0],1, r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20201222_105801_noGd_trans_withCol_coldivC1/', 
             start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=12, idx_I_before=1, idx_I_after=8)

load_plot_scan_inAx(axs[1], 1, r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_20210117_220605_noGd_trans_withCol_coldivC0p25/', 
             start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=13, idx_I_before=1, idx_I_after=9)


axs[0].set_xlabel('Wavelength'+r' ($\mathrm{\AA^{-1}}$)')
axs[1].set_xlabel('Wavelength'+r' ($\mathrm{\AA^{-1}}$)')
axs[0].set_ylabel('Intensity')

# %% [markdown]
# ## Function: overplot a scan

# %%
def load_plot_scan(path, start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=6, idx_I_before=2, idx_I_after=5, idx_I_sample=None,
                   idx_div=None,idx_div_col=None,col_div=None, longer=1):
    Scan=[]
    param = np.linspace(start_end_nb[0], start_end_nb[1], start_end_nb[2], endpoint=True) # Bender radius
    color = cm.get_cmap('jet')((param-param[0])/(param[-1]-param[0]))
    
    for i in range(start_end_nb[2]):
        Scan.append(load_results(path+str(i)+'/'))

    nS = 461

    if scanL:
        # plot P vs lambda
        for i in range(len(param)):
            if i==0:
                fig0, ax0 = my_make_plot(Scan[i][idx_pol], c=color[i], label='L=%1.3f m,'%param[i]  +  r' R$_{calc}=$%1.1f' % (param[i]**2/8/(0.06/nS)/longer) )
            else:
                ax0.errorbar(Scan[i][idx_pol].xaxis, Scan[i][idx_pol].Intensity, yerr=Scan[i][idx_pol].Error, c=color[i], 
                             label='L=%1.3f'%param[i]+' m,'  +  ' R$_{calc}=$%1.1f' % (param[i]**2/8/(0.06/nS)) )
        plt.legend(title='nSlits=%d'%nS)
        #plt.ylim([0.995,1.001])
        
        # plot I vs Lambda
        for i in range(len(param)):
            if i==0:
                fig1, ax1 = my_make_plot(Scan[i][idx_I_after]/Scan[i][idx_I_before],
                                         c=color[i], label='L=%1.3f m,' % param[i]  +  r' R$_{calc}=$%1.1f' % (param[i]**2/8/(0.06/nS)/longer) )
            else:
                ax1.errorbar(x =  Scan[i][idx_I_after].xaxis, 
                             y =  Scan[i][idx_I_after].Intensity/Scan[i][idx_I_before].Intensity, 
                             yerr=Scan[i][idx_I_after].Error    /Scan[i][idx_I_before].Intensity,
                             c=color[i], 
                             label='L=%1.3f'%param[i]+' m,'  +  r' R$_{calc}=$%1.1f' % (param[i]**2/8/(0.06/nS)/longer))
        plt.legend(title='nSlits=%d'%nS)
        
        # plot I/I at sample position
        if idx_I_sample != None:
            for i in range(len(param)):
                if i==0:
                    fig4, ax4 = my_make_plot(Scan[i][idx_I_sample[0]]/Scan[i][idx_I_sample[1]],
                                             c=color[i], label='L=%1.3f m,' % param[i]  +  r' R$_{calc}=$%1.1f' % (param[i]**2/8/(0.06/nS)/longer) )
                else:
                    ax4.errorbar(x =  Scan[i][idx_I_sample[0]].xaxis, 
                                 y =  Scan[i][idx_I_sample[0]].Intensity/Scan[i][idx_I_sample[1]].Intensity, 
                                 yerr=Scan[i][idx_I_sample[0]].Error    /Scan[i][idx_I_sample[1]].Intensity,
                                 c=color[i], 
                                 label='L=%1.3f'%param[i]+' m,'  +  r' R$_{calc}=$%1.1f' % (param[i]**2/8/(0.06/nS)/longer))
        #plt.legend(title='nSlits=%d'%nS)
        
        
        # plot H_div after bender
        if idx_div !=None:        
            fig2, ax2 = plt.subplots()     
            try: # for 1D div monitor
                xaxis = np.linspace(Scan[0][idx_div].metadata.limits[0], Scan[0][idx_div].metadata.limits[1], Scan[0][idx_div].metadata.dimension, endpoint=True)
            except: # for 2D div monitor
                xaxis = np.linspace(Scan[0][idx_div].metadata.limits[0], Scan[0][idx_div].metadata.limits[1], Scan[0][idx_div].metadata.dimension[0], endpoint=True)     
            for i in range(len(param)):
                #print(xaxis.shape, Scan[i][idx_div].Intensity.shape)
                ax2.errorbar(x =  xaxis, 
                             y =  Scan[i][idx_div].Intensity, 
                             yerr=Scan[i][idx_div].Error,
                             c=color[i], label='L=%1.3f'%param[i]+' m,'  +  r' R$_{calc}=$%1.1f' % (param[i]**2/8/(0.06/nS)/longer) )
            ax2.set_xlabel('X-divergence (deg)')
            ax2.set_xlim([-3,1.5]) #ax2.set_xlim([-0.5,2])
            ax2.set_title('Divergence after bender')
            ax2.legend(title='nSlits=%d'%nS)
        
        # plot H_div after col
        if idx_div_col !=None:
            fig3, ax3 = plt.subplots()   
            try:
                xaxis = np.linspace(Scan[0][idx_div_col[0]].metadata.limits[0], Scan[0][idx_div_col[0]].metadata.limits[1], 
                                    Scan[0][idx_div_col[0]].metadata.dimension, endpoint=True)
            except:
                xaxis = np.linspace(Scan[0][idx_div_col[0]].metadata.limits[0], Scan[0][idx_div_col[0]].metadata.limits[1], 
                                    Scan[0][idx_div_col[0]].metadata.dimension[0], endpoint=True)
                
            for i in range(len(param)):
                ax3.errorbar(x =  xaxis, 
                             y =  Scan[i][idx_div_col[0]].Intensity, 
                             yerr=Scan[i][idx_div_col[0]].Error,
                             c=color[i], label='L=%1.3f'%param[i]+' m,'  +  r' R$_{calc}=$%1.1f' % (param[i]**2/8/(0.06/nS)/longer) )
                ax3.errorbar(x =  xaxis, 
                             y =  Scan[i][idx_div_col[1]].Intensity, 
                             yerr=Scan[i][idx_div_col[1]].Error,
                             c=color[i], label='L=%1.3f'%param[i]+' m,'  +  r' R$_{calc}=$%1.1f' % (param[i]**2/8/(0.06/nS)/longer), ls='--' )
            ax3.set_xlabel('X-divergence (deg)')
            ax3.set_xlim([-3,3])
            ax3.set_title('Divergence before&after a collimator\n(after bender and arm rotation)')  
            if isinstance(col_div, str):
                ax3.text(0.1,0.8,'Collimator H_div: '+ col_div + '\nSolid lines: before col\nDashed lines: after col', transform=ax3.transAxes,size=14)
            else:
                ax3.text(0.1,0.8,'Collimator H_div: %2.0f min\nSolid lines: before col\nDashed lines: after col'%col_div, transform=ax3.transAxes,size=14)
            
        
    else:    
        for i in range(len(param)):
            if i==0:
                figs, axs = my_make_plot(Scan[i][idx_pol], c=color[i], label='R=%1.1f m,'%param[i]  +  r' L$_{calc}=$%0.3f' % np.sqrt(8*param[i]*0.06/nS))
            else:
                axs.errorbar(Scan[i][idx_pol].xaxis, Scan[i][idx_pol].Intensity, yerr=Scan[i][idx_pol].Error, c=color[i], 
                             label='R=%1.1f'%param[i]+' m,'  +  r' L$_{calc}=$%0.3f' % np.sqrt(8*param[i]*0.06/nS) )
        plt.legend(title='nSlits=%d'%nS)
        plt.ylim([0.98,1.02])

        for i in range(len(param)):
            if i==0:
                figs, axs = my_make_plot(Scan[i][idx_I_after]/Scan[i][idx_I_before], c=color[i], label='R=%1.1f m,'%param[i]  +  r' L$_{calc}=$%0.3f' % np.sqrt(8*param[i]*0.06/nS))
            else:
                axs.errorbar(x =  Scan[i][idx_I_after].xaxis, 
                             y =  Scan[i][idx_I_after].Intensity/Scan[i][idx_I_before].Intensity, 
                             yerr=Scan[i][idx_I_after].Error    /Scan[i][idx_I_before].Intensity,
                             c=color[i], label='R=%1.1f'%param[i]+' m,'  +  r' L$_{calc}=$%0.3f' % np.sqrt(8*param[i]*0.06/nS) )
    plt.show()
    try:
        return fig0,fig1,fig2,fig3, fig4, ax0, ax1, ax2, ax3, ax4, color
    except:
        return fig0,fig1, ax0, ax1, color

# %% [markdown]
# # Scan L (calc Bender radius from bender length and n slites)
# > $L=\sqrt{8R\frac{W}{N_{Slits}}}$

# %% [markdown]
# ## Scan: L= 0.05:0.01:0.15, nSlits=461
# **mcstas cmd:**
# mcrun Pol_Bender_calc_R.instr -N11 BENDERLENGTH=0.05,0.15

# %%
Scan = []
for i in range(11):
    #Scan.append(load_results(r'D:\5_Instrument\Mira_Bender\Pol_Bender_calc_R_20201026_164310/'+str(i)+'/'))
    #Scan.append(load_results(r'D:\5_Instrument\Mira_Bender\Pol_Bender_Scan_L5-15cm_Calc_Rd1p21/'+str(i)+'/')) # 10% longer than optimal, equivalent to R_opt / 1.21
    Scan.append(load_results(r'D:\5_Instrument\Mira_Bender\Pol_Bender_Scan_L5-15cm_Calc_R_with_col40/'+str(i)+'/')) # with colimator
    
param = np.linspace(0.05,0.15,11,endpoint=True) # Bender radius
color = cm.get_cmap('jet')((param-param[0])/(param[-1]-param[0]))

nS = 461
param0 = (param**2/8.0/(0.06/nS))
labels = ['L=%1.3f m, '%x  +  'R$_{calc}=$%1.3f' % y for x, y in zip(param, param0)]

for i in range(len(param)):
    if i==0:
        figs, axs = my_make_plot(Scan[i][3], c=color[i], label=labels[i])
    else:
        axs.errorbar(Scan[i][3].xaxis, Scan[i][3].Intensity, yerr=Scan[i][3].Error, c=color[i], 
                     label=labels[i])
plt.legend(title='nS=%d' % nS)
plt.show()

for i in range(len(param)):
    if i==0:
        figs, axs = my_make_plot(Scan[i][4],c=color[i], label=labels[i])
    else:
        axs.errorbar(Scan[i][3].xaxis, Scan[i][4].Intensity, yerr=Scan[i][4].Error,c=color[i], 
                     label=labels[i])
plt.legend(title='nS=%d' % nS)
plt.show()

# Flipping ratio: (1+P)/(1-P)
fig, ax = plt.subplots()
for i in range(len(param)):
    ax.plot(Scan[i][3].xaxis, (1+Scan[i][3].Intensity) / (1-Scan[i][3].Intensity), c=color[i], label=labels[i])
ax.legend(title='nS=%d'%nS)
plt.title('Flipping ratio: '+r'$\frac{1+P}{1-P}$')
plt.show()

# %%
make_sub_plot(Scan[10])

# %% [markdown]
# # Scan R (calc Bender length from bender radius and n slites)
# > $L=\sqrt{8R\frac{W}{N_{Slits}}}$

# %% [markdown]
# ## Scan: R=2.5 : 0.1 : 3.5, nSlits=461
# **mcstas cmd:**
# *mcrun Pol_Bender_calc_L.instr -N11 BENDERRADIUS=2.5,3.5*

# %%
Scan = []
for i in range(11):
    Scan.append(load_results(r'D:\5_Instrument\Mira_Bender\Pol_Bender_calc_L_20201026_151625/'+str(i)+'/'))
    
param = np.linspace(2.5,3.5,11,endpoint=True) # Bender radius
color = cm.get_cmap('jet')((param-param[0])/(param[-1]-param[0]))

nS = 461

for i in range(len(param)):
    if i==0:
        figs, axs = my_make_plot(Scan[i][3], c=color[i], label='R=%1.1f m,'%param[i]  +  ' L$_{calc}=$%0.3f' % np.sqrt(8*param[i]*0.06/nS))
    else:
        axs.errorbar(Scan[i][3].xaxis, Scan[i][3].Intensity, yerr=Scan[i][3].Error, c=color[i], 
                     label='R=%1.1f'%param[i]+' m,'  +  ' L$_{calc}=$%0.3f' % np.sqrt(8*param[i]*0.06/nS) )
plt.legend(title='nS=%d'%nS)
plt.show()

for i in range(len(param)):
    if i==0:
        figs, axs = my_make_plot(Scan[i][4],c=color[i], label='R=%1.1f m,'%param[i]  +  ' L$_{calc}=$%0.3f' % np.sqrt(8*param[i]*0.06/nS))
    else:
        axs.errorbar(Scan[i][3].xaxis, Scan[i][4].Intensity, yerr=Scan[i][4].Error,c=color[i], 
                     label='R=%1.1f'%param[i]+' m,'  +  ' L$_{calc}=$%0.3f' % np.sqrt(8*param[i]*0.06/nS) )
plt.legend(title='nS=%d'%nS)
plt.show()

# Flipping ratio: (1+P)/(1-P)
fig, ax = plt.subplots()
for i in range(len(param)):
    ax.plot(Scan[i][3].xaxis, (1+Scan[i][3].Intensity) / (1-Scan[i][3].Intensity), c=color[i], label='R=%1.1f'%param[i]+' m,'  +  ' L$_{calc}=$%0.3f' % np.sqrt(8*param[i]*0.06/50) )
ax.legend(title='nS=%d'%nS)
plt.title('Flipping ratio: '+r'$\frac{1+P}{1-P}$')
plt.show()

# %% [markdown]
# ## Scan R:5-15 m, nSlits=50

# %%
# L=sqrt(8Rd) = sqrt(8R*w/n)
Rs = np.linspace(5,15,11,endpoint=True)
Ls = np.sqrt(8*Rs*0.06/50)
print(Ls)

# %%
Scan = []
for i in range(11):
    Scan.append(load_results(r'D:\5_Instrument\Mira_Bender\Pol_Bender_calc_L_20201025_220049/'+str(i)+'/'))
    
param = np.linspace(5,15,11,endpoint=True) # Bender radius    
color = cm.get_cmap('jet')((param-param[0])/(param[-1]-param[0]))

nS = 50

for i in range(len(param)):
    if i==0:
        figs, axs = my_make_plot(Scan[i][3], c=color[i], label='R=%1.1f m,'%param[i]  +  ' L$_{calc}=$%0.3f' % np.sqrt(8*param[i]*0.06/nS))
    else:
        axs.errorbar(Scan[i][3].xaxis, Scan[i][3].Intensity, yerr=Scan[i][3].Error, c=color[i], 
                     label='R=%1.1f'%param[i]+' m,'  +  ' L$_{calc}=$%0.3f' % np.sqrt(8*param[i]*0.06/nS) )
plt.legend(title='nS=%d'%nS)
plt.show()

for i in range(len(param)):
    if i==0:
        figs, axs = my_make_plot(Scan[i][4],c=color[i], label='R=%1.1f m,'%param[i]  +  ' L$_{calc}=$%0.3f' % np.sqrt(8*param[i]*0.06/nS))
    else:
        axs.errorbar(Scan[i][3].xaxis, Scan[i][4].Intensity, yerr=Scan[i][4].Error,c=color[i], 
                     label='R=%1.1f'%param[i]+' m,'  +  ' L$_{calc}=$%0.3f' % np.sqrt(8*param[i]*0.06/nS) )
plt.legend(title='nS=%d'%nS)
plt.show()

# Flipping ratio: (1+P)/(1-P)
fig, ax = plt.subplots()
for i in range(len(param)):
    ax.plot(Scan[i][3].xaxis, (1+Scan[i][3].Intensity) / (1-Scan[i][3].Intensity), c=color[i], label='R=%1.1f'%param[i]+' m,'  +  ' L$_{calc}=$%0.3f' % np.sqrt(8*param[i]*0.06/50) )
ax.legend(title='nS=%d'%nS)
plt.title('Flipping ratio: '+r'$\frac{1+P}{1-P}$')
plt.show()

# %% [markdown]
# # Scan Bender length: fix R=10m, W=0.06m and nSlits=50

# %%
Scan = []
for i in range(5):
    Scan.append(load_results(r'D:\5_Instrument\Mira_Bender\Pol_Bender_20201022_230552/'+str(i)+'/'))
for i in range(9):
    Scan.append(load_results(r'D:\5_Instrument\Mira_Bender\Pol_Bender_20201022_232514/'+str(i)+'/'))
for i in range(5):
    Scan.append(load_results(r'D:\5_Instrument\Mira_Bender\Pol_Bender_20201022_224435/'+str(i)+'/'))

# %%
BenderL = np.hstack([np.linspace(0.06,0.14,5,endpoint=True),
                     np.linspace(0.142,0.158,9,endpoint=True),
                     np.linspace(0.16,0.24,5,endpoint=True)])

color = cm.jet(BenderL/0.24)
for i in range(19):
    if i==0:
        figs, axs = my_make_plot(Scan[i][3], c=color[i],label='0.06cm')
    else:
        axs.errorbar(Scan[i][3].xaxis, Scan[i][3].Intensity, yerr=Scan[i][3].Error, c=color[i], label='%0.3f'%BenderL[i]+'cm')

plt.legend(title='R=10m,nS=50,\nL are')
plt.show()

for i in range(19):
    if i==0:
        figs, axs = my_make_plot(Scan[i][4],c=color[i],label='0.06cm')
    else:
        axs.errorbar(Scan[i][3].xaxis, Scan[i][4].Intensity, yerr=Scan[i][4].Error,c=color[i], label='%0.3f'%BenderL[i]+'cm')
plt.legend(title='R=10m,nS=50,\nL are')
plt.show()
make_sub_plot(Scan[10])

# %% [markdown]
# # Scan Bender R at fixed Bender length=0.154 (save P max I)

# %%
Scan = []
for i in range(11):
    Scan.append(load_results(r'D:\5_Instrument\Mira_Bender\Pol_Bender_20201024_214626/'+str(i)+'/'))

# %%
BenderR = np.linspace(5,15,11,endpoint=True)
color = cm.jet(BenderR/15)
for i in range(11):
    if i==0:
        figs, axs = my_make_plot(Scan[i][3], c=color[i], label='5m')
    else:
        axs.errorbar(Scan[i][3].xaxis, Scan[i][3].Intensity, yerr=Scan[i][3].Error,c=color[i], label='%0.3f'%BenderR[i]+'m')
plt.legend(title='L=0.154m,nS=50,\nR are')
plt.show()

for i in range(11):
    if i==0:
        figs, axs = my_make_plot(Scan[i][4], c=color[i],label='5m')
    else:
        axs.errorbar(Scan[i][3].xaxis, Scan[i][4].Intensity, yerr=Scan[i][4].Error,c=color[i], label='%0.3f'%BenderR[i]+'m')
plt.legend(title='L=0.154m,nS=50,\nR are')
plt.show()
make_sub_plot(Scan[10])

# %% [markdown]
# # Compare pol_Bender and Bender

# %% [markdown]
# 1. pol_Bender with
#
# rLeftUpPar     ={0.99, 0.0217, 2.6, 3.6, 0.0001},
#
# rLeftDownPar={0.99, 0.0130, 0.0, 1.0, 0.0001})
#
# 2. Two runs with Bender with parameters for spin up and spin down separately

# %% [markdown]
# Mcstas code
#
# /* Spin  positive Y */
# COMPONENT bender = Bender(w=0.06, h=0.12, r=BENDERRADIUS, k=NSLITS, d=WSPACER, l=BENDERLENGTH,
#     R0a=0.99, Qca=0.0217, alphaa=2.6, ma=3.6, Wa=0.0001,
#     R0i =0.99, Qci =0.0217, alphai= 2.6, mi=3.6, Wi=0.0001,
#     R0s =0.99, Qcs =0.0217, alphas=2.6, ms=3.6, Ws=0.0001)
#     AT (0, 0, BENDER_Z) RELATIVE Origin
#
# /* Spin: minus Y */
# COMPONENT bender = Bender(w=0.06, h=0.12, r=BENDERRADIUS, k=NSLITS, d=WSPACER,l=BENDERLENGTH,
#     R0a=0.99, Qca=0.013, alphaa=0, ma=1.0, Wa=0.0001,
#     R0i =0.99, Qci =0.013, alphai= 0, mi=1.0, Wi=0.0001,
#     R0s =0.99, Qcs =0.013, alphas=0, ms=1.0, Ws=0.0001)
#     AT (0, 0, BENDER_Z) RELATIVE Origin

# %% [markdown]
# ## 3rd compare: L=0.06, R=3m, nSlits=461

# %%
# Old Pol_Bender and Bender
# data0 = load_results(r'D:\5_Instrument\Mira_Bender\Pol_Bender_20201026_161923/')

# data1 = load_results(r'D:\5_Instrument\Mira_Bender\Bender_20201026_161524/') # Spin up,   100,000,000
# data2 = load_results(r'D:\5_Instrument\Mira_Bender\Bender_20201026_161720/') # Spin down, 100,000,000

# New with 0.5-9A, Bender_calc_R_col_div
data0 = load_results(r'D:\5_Instrument\Mira_Bender\Pol_Bender_calc_R_col_div_20201116_173617/0')
data1 = load_results(r'D:\5_Instrument\Mira_Bender\Bender_calc_R_col_div_spin_up/0') # Spin up,   100,000,000
data2 = load_results(r'D:\5_Instrument\Mira_Bender\Bender_calc_R_col_div_spin_down/0') # Spin down, 100,000,000

make_sub_plot(data0)
make_sub_plot(data1)
make_sub_plot(data2)

# %% [markdown]
# - **Compare:**
#
# pol_Bender: polarization, intensiy
#
# **VS**
#
# Bender with params for $\uparrow$ and $\downarrow$: $\frac{I(\uparrow)-I(\downarrow)}{I(\uparrow)+I(\downarrow)}$, ($I(\uparrow)+I(\downarrow)$)/2

# %%
# Old Pol_Bender and Bender
# overplot
# Polarization
figs, axs = my_make_plot(data0[3], label='pol_Bender')

axs.plot(data1[3].xaxis, (data1[3].Intensity-data2[3].Intensity) / (data1[3].Intensity+data2[3].Intensity), label='Bender_2runs '+r'$\frac{I(\uparrow)-I(\downarrow)}{I(\uparrow)+I(\downarrow)}$')

plt.legend()
plt.show()

# Intensity
figs, axs = my_make_plot(data0[4],label='pol_Bender')
axs.plot(data1[3].xaxis, (data1[3].Intensity+data2[3].Intensity)/2, label='Bender_2runs '+r'($I(\uparrow)+I(\downarrow)$)/2')
plt.legend()
plt.show()

# %%
# New with 0.5-9A, Bender_calc_R_col_div
# overplot
# Polarization
figs, axs = my_make_plot(data0[6], label='pol_Bender')

axs.plot(data1[5].xaxis, (data1[5].Intensity-data2[5].Intensity) / (data1[5].Intensity+data2[5].Intensity), label='Bender_2runs '+r'$\frac{I(\uparrow)-I(\downarrow)}{I(\uparrow)+I(\downarrow)}$')

plt.legend()
plt.show()

# Intensity
figs, axs = my_make_plot(data0[5],label='pol_Bender')
axs.plot(data1[5].xaxis, (data1[5].Intensity+data2[5].Intensity)/2, label='Bender_2runs '+r'($I(\uparrow)+I(\downarrow)$)/2')
plt.legend()
plt.show()

# Divergenct       
fig, axs = plt.subplots()        
xaxis = np.linspace(data0[7].metadata.limits[0], data0[7].metadata.limits[1], data0[7].metadata.dimension[0], endpoint=True)
axs.errorbar(x = xaxis, y = data0[7].Intensity.sum(axis=0), yerr=data0[7].Error.sum(axis=0),label='Pol_Bender')
axs.errorbar(x = xaxis, y = data1[7].Intensity.sum(axis=0)/2, yerr=data1[7].Error.sum(axis=0)/2,label='Bender' )
axs.set_xlabel('X-divergence (deg)')
axs.set_xlim([-0.5,2])
axs.set_title('Divergence after bender')
axs.text(0.5,0.5,"Two benders are bended to different direction",transform=axs.transAxes)
axs.legend()
plt.show()

# %% [markdown]
# ## 2nd comapre:  L=0.2, R=10m, nSlits = 461

# %%
data0 = load_results(r'D:\5_Instrument\Mira_Bender\Pol_Bender_20201026_160719/')

data1 = load_results(r'D:\5_Instrument\Mira_Bender\Bender_20201026_160432/') # Spin up,   100,000,000
data2 = load_results(r'D:\5_Instrument\Mira_Bender\Bender_20201026_160241/') # Spin down, 100,000,000

make_sub_plot(data0)
make_sub_plot(data1)
make_sub_plot(data2)

# %%
# overplot
figs, axs = my_make_plot(data0[3], label='pol_Bender')

axs.plot(data1[3].xaxis, (data1[3].Intensity-data2[3].Intensity) / (data1[3].Intensity+data2[3].Intensity), label='Bender_2runs')

plt.legend()
plt.show()

figs, axs = my_make_plot(data0[4],label='pol_Bender')
axs.plot(data1[3].xaxis, (data1[3].Intensity+data2[3].Intensity)/2, label='Bender_2runs')
plt.legend()
plt.show()

# %% [markdown]
# ## Fist compare: L=0.2, R=10m, nSlits = 50

# %%
np.sin(0.2/10)*1.6*100

# %%
data0 = load_results(r'D:\5_Instrument\Mira_Bender\Pol_Bender_20201022_161159/')

data1 = load_results(r'D:\5_Instrument\Mira_Bender\Bender_20201022_171659/') # Spin up,   100,000,000
data2 = load_results(r'D:\5_Instrument\Mira_Bender\Bender_20201022_172004/') # Spin down, 100,000,000

make_sub_plot(data0)
make_sub_plot(data1)
make_sub_plot(data2)

# %%
figs, axs = my_make_plot(data0[3], label='pol_Bender')

axs.plot(data1[3].xaxis, (data1[3].Intensity-data2[3].Intensity) / (data1[3].Intensity+data2[3].Intensity), label='Bender_2runs')

plt.legend()
plt.show()

figs, axs = my_make_plot(data0[4],label='pol_Bender')
axs.plot(data1[3].xaxis, (data1[3].Intensity+data2[3].Intensity)/2, label='Bender_2runs')
plt.legend()
plt.show()

# %%
print(data[0].__dict__)
print(data[0].metadata.__dict__)
print(data[0].plot_options.__dict__)

# %%
print(data[6].metadata.info)
data[6].xaxis

# %%
plt.close('all')

# %%
figs, axs = my_make_plot(data0)

# %% [markdown]
# # Reproduce PF1D Fig.6

# %%
#make_sub_plot(load_results(r'D:\5_Instrument\Mira_Bender_ref_tran/0_Pol_Bender_calc_R_col_div_simpler_reproduce_Fig6_20210121_153306_m3p2_div2_absorb'))
#make_sub_plot(load_results(r'D:\5_Instrument\Mira_Bender_ref_tran/0_Pol_Bender_calc_R_col_div_simpler_reproduce_Fig6_20210121_150013_m3p6_div2_noAbsorb'))
make_sub_plot(load_results(r'D:\5_Instrument\Mira_Bender_ref_tran/0_Pol_Bender_calc_R_col_div_simpler_reproduce_Fig6_v_bender_absorb'))

# %% [markdown]
# ## calcs

# %% [markdown]
# ### V-bender: beam parallel to the first part

# %%
# V-Bender
w, l, d, m_up, m_dn = 0.06, 0.05, 0.000180, 3.2,0.33
gap = w*np.sin(5*d/l)*1000 # gap size of the two parts of the bender at the outer side
angle = 5*d/l *180/3.14 # bend angle
gamma_up, gamma_dn = m_up * 1.73 * 5 /1000 *180/3.14, m_dn * 1.73 * 15 /1000 *180/3.14 # total ref angle for 5A 15A
absorb_dw =np.cos(gamma_dn/180*3.14)

lam_up_cut, lam_dn_cut = angle/2/(m_up*1.73/1000*180/3.14), angle/2/(m_dn*1.73/1000*180/3.14) # lam_cut for spin up
print(angle, gamma, lam_up_cut, lam_dn_cut, absorb_dw)

# %%
# V-Bender theta_c(direct view) and m_2
0.5/180*3.14/(1.73 * 2 /1000)
theta_c = 4*d/l*180/3.14 # critical bending angle for direct view
m_2 = 4*d/l/(1.73*2/1000)
print(theta_c, m_2)

# %%
# V-bender: lam_cut for spin down
m_up_dn = np.array([4,0.33])
4*d/l/2/(1.73*m_up_dn/1000)

# %%
# V-bender max nb of ref.
w, l, d, m_up, m_dn = 0.06, 0.05, 0.000130, 4.0 ,0.33
gamma_up = m_up * 1.73 * 5 /1000
max_num_of_ref = l/(d/np.tan(gamma_up)) # max num of ref for 5A

# %% [markdown]
# ### V-bender: beam parallel to direct view

# %%
# V-Bender theta_c(direct view) and m_2
w, l, d, div = 0.06, 0.05, 0.000180, 1.0/180*3.14

theta_c = 4*d/l # critical bending angle for direct view
m_1 = (div+theta_c)/2/(1.73*2/1000)
m_2 = m_1 + theta_c/(1.73*2/1000)
print(theta_c*180/3.14, m_1, m_2)

# %%
theta_c/(1.73*2/1000)

# %% [markdown]
# ### C-Bender

# %%
# C-Bender lam_c for spin up/down
m_up_dn = np.array([3.5,0.33])
l, d, r = 0.05, 0.000130, 2.2
lam_c_up_dn = (2*d/r)**0.5 / (m_up_dn*1.73) *1e3
print(lam_c_up_dn)

max_num_of_ref = l/(d/np.tan(m_up_dn[0] * 1.73 * 5 /1000))# max num of ref for 5A
print(max_num_of_ref, 0.99**int(max_num_of_ref))

# %% [markdown]
# ## plots

# %%
plt.close('all') 
#data = load_results(r'D:\5_Instrument\Mira_Bender_ref_tran/0_Pol_Bender_calc_R_col_div_simpler_reproduce_Fig6_20210121_145208_m3p6_div2_absorb')
#data = load_results(r'D:\5_Instrument\Mira_Bender_ref_tran/0_Pol_Bender_calc_R_col_div_simpler_reproduce_Fig6_20210121_150013_m3p6_div2_noAbsorb')

data = load_results(r'D:\5_Instrument\Mira_Bender_ref_tran/0_Pol_Bender_calc_R_col_div_simpler_reproduce_Fig6_v_bender_20210311_230417')
#data = load_results(r'D:\5_Instrument\Mira_Bender_ref_tran/0_Pol_Bender_calc_R_col_div_simpler_reproduce_Fig6_20210121_162256_m3p2_div2_absorb_rDiv1p44')
#data = load_results(r'D:\5_Instrument\Mira_Bender_ref_tran/0_Pol_Bender_calc_R_col_div_simpler_reproduce_Fig6_20210122_113531')
#data = load_results(r'D:\5_Instrument\Mira_Bender_ref_tran/0_Pol_Bender_calc_R_col_div_simpler_reproduce_Fig6_20210121_154538_m3p2_div3_absorb')
#data = load_results(r'D:\5_Instrument\Mira_Bender_ref_tran/0_Pol_Bender_calc_R_col_div_simpler_reproduce_Fig6_20210121_153939_m3p2_div4_absorb')

# V bender
data = load_results(r'D:\5_Instrument\Mira_Bender_ref_tran/0_Pol_Bender_calc_R_col_div_simpler_reproduce_Fig6_v_bender_absorb')

idx_pol = 2
fig, ax = my_make_plot(data[idx_pol])
ax.set_xlim((0,20))

idx_I_before, idx_I_after =0, 3
fig, ax = my_make_plot(data[idx_I_after]/data[idx_I_before]/0.5 )
ax.set_xlim((0,20))
ax.yaxis.set_ticks(np.arange(0,0.9,0.1))

fig, ax = my_make_plot(data[4]/data[idx_I_before]/0.5/0.5, c='grey',marker='s' ) #/0.5 for normalizing to spin-up, /0.5 to corrected bender error
ax.set_xlim((0,20))
ax.set_ylim((0,1.1))
ax.yaxis.set_ticks(np.arange(0,1.1,0.1))
ax.set_ylabel('Transmission (of spin-up)')
ax0 = ax.twinx()
ax0.errorbar(data[idx_pol].xaxis, data[idx_pol].Intensity, data[idx_pol].Error*0, c='black',marker='s')
ax0.set_ylim((0.5,1.05))
ax0.yaxis.set_ticks(np.arange(0.5,1.05,0.1))
ax0.set_ylabel('Polarization')

ax.arrow( 2.5, 0.7,-1, 0, width=0.01, head_length=1, color='grey')
ax0.arrow(15,0.9,   2, 0, width=0.01, head_length=1, color='black')

# %% [markdown]
# # Compare straight and bend

# %%
def bend_straight(path0, path1, start_end_nb = [0.03,0.13,11], idx_I_after=6, longer=1.1):
    param = np.linspace(start_end_nb[0], start_end_nb[1], start_end_nb[2], endpoint=True) # Bender scan parameter
    Scan0, Scan1 = [], []  
    for i in range(11):
        Scan0.append(load_results(path0+str(i)+'/'))
        Scan1.append(load_results(path1+str(i)+'/'))

    nS = 461    
    # plot I vs Lambda
    for i in range(len(param)):
        if i==0:
            fig, ax = my_make_plot(Scan0[i][idx_I_after]/Scan1[i][idx_I_after],
                                     c=color[i], label='L=%1.3f m,' % param[i]  +  r' R$_{calc}=$%1.1f' % (param[i]**2/8/(0.06/nS)/longer) )
        else:
            ax.errorbar(x =  Scan0[i][idx_I_after].xaxis, 
                         y =  Scan0[i][idx_I_after].Intensity/Scan1[i][idx_I_after].Intensity, 
                         yerr=Scan0[i][idx_I_after].Error    /Scan1[i][idx_I_after].Intensity,
                         c=color[i], 
                         label='L=%1.3f'%param[i]+' m,'  +  r' R$_{calc}=$%1.1f' % (param[i]**2/8/(0.06/nS)/longer))
    plt.legend(title='nSlits=%d'%nS)
    return fig, ax

# %%
*figsaxs, color = load_plot_scan(path1, start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=4, idx_I_before=1, idx_I_after=6, 
                   idx_div=None,idx_div_col=None,col_div=None, longer=longer)
figs, axs = figsaxs[:int(len(figsaxs)/2)], figsaxs[int(len(figsaxs)/2):]
figs[0].set_size_inches(5, 4, forward=True)
figs[1].set_size_inches(5, 4, forward=True)
axs[0].set_ylim([-0.05,1.05])

# %%
path0 = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div2/'
path1 = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div2p0_2p0_absorb/'
path2 = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div2p0_2p0_straight/'
path3 = r'D:\5_Instrument\Mira_Bender_ref_tran\0_Pol_Bender_calc_R_col_div_simpler_sample_div2p0_2p0_absorb_straight/'


# *figsaxs, color = load_plot_scan(path0, start_end_nb = [0.03,0.13,11], scanL=True, idx_pol=4, idx_I_before=1, idx_I_after=6, 
#                    idx_div=None,idx_div_col=None,col_div=None, longer=longer)
# figs, axs = figsaxs[:int(len(figsaxs)/2)], figsaxs[int(len(figsaxs)/2):]
# figs[0].set_size_inches(5, 4, forward=True)
# figs[1].set_size_inches(5, 4, forward=True)
# axs[0].set_ylim([-0.05,1.05])

# for i in range(11):
#     #plot vertical lines at the critical lambda
#     axs[1].axvline(Lc[i], color=color[i], ls='--')
#     #plot analytical results
#     axs[1].plot(lams, trans_ref(lams,Lc[i]), color=color[i], ls='dotted')


# Bend/straight
fig, ax = bend_straight(path0,path2)
fig.set_size_inches(5, 4, forward=True)
for i in range(11):
    #plot vertical lines at the critical lambda
    ax.axvline(Lc[i], color=color[i], ls='--')
    #plot analytical results
    ax.plot(lams, 2*trans_ref(lams,Lc[i]), color=color[i], ls='dotted')
    
# Bend_absorb/straight    
fig, ax = bend_straight(path1,path2)
fig.set_size_inches(5, 4, forward=True)
for i in range(11):
    #plot vertical lines at the critical lambda
    ax.axvline(Lc[i], color=color[i], ls='--')
    #plot analytical results
    ax.plot(lams, 2*trans_ref(lams,Lc[i]), color=color[i], ls='dotted')
    
    
# Bend_absorb/straight， trans_ref_absorb    
fig, ax = bend_straight(path1,path2)
fig.set_size_inches(5, 4, forward=True)
for i in range(11):
    #plot vertical lines at the critical lambda
    ax.axvline(Lc[i], color=color[i], ls='--')
    #plot analytical results
    ax.plot(lams, 2*trans_ref_absorb(lams,Lc[i], 3.6, Ls[i], Rs[i]), color=color[i], ls='dotted')

# %% [markdown]
# # StdReflecFunc plot

# %%
from latexify import latexify
latexify()
plt.close('all')

# %%
# Plot the  stdreflecfunc of mcstas
def Stdreflecfunc(q, R0, Qc, alpha, m, W):
    if q<=Qc:
        return R0
    else:
        arg = (q-Qc*m)/W
        return R0*0.5*(1 - np.tanh(arg))*(1 - alpha*(q - Qc))
    
def Stdreflecfunc(q, R0, Qc, alpha, m, W, beta):
    """Qc is the real critical Q of the mirror not that of natural nikel
       m: relative to the real Qc
    """
    if (W==0) & (alpha==0):
        m=m*0.9853+0.1978
        W=-0.0002*m+0.0022
        alpha=0.2304*m+5.0944
        beta=-7.6251*m+68.1137
        if (m<=3):
            alpha=m
            beta=0

    arg = (q - m*Qc)/W if W > 0 else 11

    if (arg > 10) | (m <= 0) | (Qc <=0) | (R0 <= 0):
        return 0
    
    if m < 1:
        Qc *= m
        m=1
        
    if (q <= Qc):
        return R0
    
    return R0*0.5*(1 - np.tanh(arg))*(1 - alpha*(q - Qc) + beta*(q - Qc)*(q - Qc))

def Stdreflecfunc_plot(ax, R0, Qc, alpha, m, W, beta, maxQm=6.5, **kwargs):
    #maxqm = 1.1*m if m>1 else 2*m
    Qc_Ni = 0.0216
    muli_Ni = np.linspace(0,maxQm, num=10001, endpoint=True)
    rs = [Stdreflecfunc(multi*Qc_Ni, R0, Qc, alpha, m, W, beta) for multi in muli_Ni]
    ax.plot(muli_Ni, rs, **kwargs)
    ax.set_xlabel(r'm [$\mathrm{Q/Q_C}$(Ni)]')
    ax.set_ylabel('Reflectivity')
    #return ax

    
R0, Qc, alpha, m, W, beta = 0.99, 0.0217, 2.6, 3.60, 0.001, 0
R0, Qc, alpha, m, W, beta = 0.99, 0.0217, 0.0, 0.0,  0.1, 1

fig1, ax1 = plt.subplots()#figsize=(5,4))
# Reproducing paper result
#Stdreflecfunc_plot(ax1, 0.99, 0.0216, 4, 3.2,  0.001, 0, label='Spin-up',ls='--', c='black')
#Stdreflecfunc_plot(ax1, 0.99, 0.0216, 0.0, 0.4, 0.001, 0, label='Spin-down',ls='--', c='red')

# Our v-bender
Stdreflecfunc_plot(ax1, 0.99, 0.0217, 2.6, 5.50, 0.001, 0, label='Spin-up',ls='-', c='black')
Stdreflecfunc_plot(ax1, 0.99, 0.0217, 0.0, 0.33, 0.001, 0, label='Spin-down',ls='-', c='red')

# Stdreflecfunc_plot(ax1, 0.99, 0.0216,2.6, 3.5,  0.001, 0, label='Spin-up (1 mirror)',ls='--', c='black')
# Stdreflecfunc_plot(ax1, 0.99, 0.0216, 0.0, 0.33, 0.001, 0, label='Spin-down (1 mirror)',ls='--', c='red')

# Stdreflecfunc_plot(ax1, 0.99, 0.0216, 0.0, 3.5,  0.001, -2.6**2, label='Spin-up (doule mirrors)',c='black')
# Stdreflecfunc_plot(ax1, 0.99, 0.0216, 0.0, 0.33, 0.001, 0, label='Spin-down (double mirrors)', c='red')

dat = np.genfromtxt(r'D:\5_Instrument\Mira_Bender\SwissN_FeSi.txt', delimiter=',')
ax1.scatter(dat[:,0], dat[:,1], s=5, label='Measured (Ref. [22])')

ax1.legend()
ax2 = ax1.twiny()
ax2.set_xticks(ax1.get_xticks())
ax2.set_xbound(ax1.get_xbound())
ax2.set_xticklabels([np.round(x*0.0217,decimals=3) for x in ax1.get_xticks()])
ax2.set_xlabel('$Q  (\mathrm{\AA}^{-1}$)')
ax2.grid(False)



#plt.tight_layout(pad=5)
fig1.savefig(r'D:\7_Writing\1_Paper Draft\10_MiraBender/r-q.pdf',bbox_inches="tight",pad_inches=0.01)
plt.show()

# qs = np.linspace(0,5, num=10001, endpoint=True)
# rs = [Stdreflecfunc(q*Qc, R0, Qc, alpha, m, W, beta) for q in qs]
# fig, ax1 = plt.subplots()
# ax1.plot(qs, rs)
# ax1.set_xlabel('m')
# ax1.set_ylabel('R')

# ax2 = ax1.twiny()
# ax2.set_xticks(ax1.get_xticks() )
# ax2.set_xbound(ax1.get_xbound())
# ax2.set_xticklabels([np.round(x *Qc,3) for x in ax1.get_xticks()])
# ax2.set_xlabel('$Q_\mathrm{z} (\mathrm{\AA}^{-1}$)')

# plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
1.73*4*3.14/1000

# %%
### Reproduce spin down reflection curve for Silicon and Sapphire subtrates
si = np.genfromtxt(r'D:\5_Instrument\Mira_Bender\Mira_Bender_coldS/V-bende_Silicon_down_ref_curve.txt',delimiter=',')
sa = np.genfromtxt(r'D:\5_Instrument\Mira_Bender\Mira_Bender_coldS/V-bende_Sapphire_down_ref_curve.txt',delimiter=',')
fig1, ax1 = plt.subplots(figsize=(5,4))

ax1.scatter(si[:,0],si[:,1],label='Si (ILL paper)')
ax1.scatter(sa[:,0],sa[:,1],label='Sapphire (ILL paper)')
Stdreflecfunc_plot(ax1, 1, 0.0216, 0, 0.33, 0.001,  0, label='McStas m={:1.2f} w={:1.4f}'.format(0.33,0.001), ls='-', c='black',maxQm=1.4)
Stdreflecfunc_plot(ax1, 1, 0.0216, 0, 0.025, 0.0035, 0, label='McStas m={:1.3f} w={:1.4f}'.format(0.025,0.0035),ls='-', c='red',maxQm=1.4)

ax1.legend(handletextpad=0)
ax2 = ax1.twiny()
ax2.set_xticks(ax1.get_xticks())
ax2.set_xbound(ax1.get_xbound())
ax2.set_xticklabels([np.round(x*0.0216,decimals=4) for x in ax1.get_xticks()])
ax2.set_xlabel('$Q_\mathrm{z} (\mathrm{\AA}^{-1}$)')
ax2.grid(False)
plt.tight_layout(pad=5)
plt.show()

# %%
plt.close('all')

# %%
1-2.6*0.054
0.2/0.054
0.2/(0.098-0.022)
(0.00013/2.2)**0.5*180/3.14
(0.00013/2.2)**0.5/(1.73*2/1000)
0.2/0.076
0.001*180/3.14
print(np.arctan(0.00013/0.01)*180/3.14)
# Q for natural Ni
def gammac_qc(rou0, rou1, lambda0=1):
    """
    Function calculating total reflection angle gamma_c and Q
    Inputs:
    rou1 and rou2 : neutrion scattering density medium in 1e-6 A^-2 substrate, supermirror
                    rou2>rou1
    Return: gamma_c in rad. and qc in the unit of inverse unite of lambda0
    """
    if rou0>rou1:
        print('No total reflection because rou0>rou1')
        return
    gammac = lambda0*np.sqrt((rou1-rou0)*1e-6/np.pi)
    qc =  4*np.pi/lambda0*np.sin(gammac)
    return gammac, qc

print('Nikel critical angle (rad.) for 1A', np.sqrt(9.4e-6/np.pi))
print('Nikel crital Q', 4*np.pi*np.sin(1.73e-3))
for rou0, rou1, text in zip([0,        2.08,        2.08,        4.19,             4.19,            -1.93,           0,           0,            6.38,      -2.14], 
                            [9.4,      12.97,       3.08,        (12.97+6.38)/2,   (3.08-2.14)/2,   (12.97+6.38)/2,  6.38,        -2.14,        6.55,       6.55],
                            ['Air-Ni', 'Si-Fe(up)', 'Si-Fe(dw)', 'SiO2-FeCoV(up)', 'SiO2-FeCoV(dw)', 'Ti-FeCoV(up)', 'Air-Co(up)', 'Air-Co(dw)', 'Co-Cu(up)','Co-Cu(dw)']):
    print(text, gammac_qc(rou0,rou1))

# %% [markdown]
# ## Curve from Kris

# %%
plt.close('all')
# Fe/Si
# m_r = np.array([[2,90], [2.5, 86],[3, 82],[3.5,77],[4,73],[4.5,68]])
# fig, ax1 = plt.subplots()
# ax1.plot(m_r[:,0], m_r[:,1]/100, 'o', label='Kris')
# Stdreflecfunc_plot(ax1, 0.99, 0.0216, 4.0, 4.5, 0.0001, 0, 5, label=r'McStas  m={} $\alpha$={} EdgeWidth={}'.format(4.5,4.0, 1e-4) ,ls='-')
# Stdreflecfunc_plot(ax1, 0.99, 0.0216, 2.6, 4.5, 0.001, 0, 5, label=r'SwissN. m={} $\alpha$={} EdgeWidth={}'.format(4.5,2.6, 1e-3) ,ls='-',zorder=1)
# #ax1.set_xlim([0,6])
# ax1.legend(handletextpad=0.5)
# ax2 = ax1.twiny()
# ax2.set_xticks(ax1.get_xticks())
# ax2.set_xbound(ax1.get_xbound())
# ax2.set_xticklabels([np.round(x*0.0216,decimals=4) for x in ax1.get_xticks()])
# ax2.set_xlabel('$Q_\mathrm{z} (\mathrm{\AA}^{-1}$)')
# ax2.grid(False)
# plt.tight_layout(pad=5)
# plt.show()
# Co/Cu
from io import StringIO
m_r_dw = """0.10381471389645777, 0.9138686131386862
        0.11335149863760219, 0.9051094890510949
        0.12193460490463215, 0.981021897810219
        0.13115349682107175, 0.9868613138686131
        0.14005449591280655, 0.9737226277372262
        0.1499091734786558, 1.0043795620437956
        0.15944595821980018, 1
        0.1689827429609446, 0.9518248175182482
        0.17756584922797458, 0.9722627737226277
        0.18678474114441418, 0.9226277372262773
        0.1963215258855586, 0.9211678832116788
        0.205858310626703, 0.9226277372262773
        0.22524977293369663, 0.8613138686131387
        0.23383287920072662, 0.8627737226277372
        0.2424159854677566, 0.8262773722627736
        0.25227066303360585, 0.8175182481751825
        0.26148955495004544, 0.8029197080291971
        0.27102633969118983, 0.7883211678832116
        0.28088101725703907, 0.7781021897810219
        0.2897820163487739, 0.8087591240875912
        0.2996366939146231, 0.8014598540145985
        0.3085376930063579, 0.7751824817518248
        0.3180744777475023, 0.7795620437956203
        0.3276112624886467, 0.7343065693430656
        0.3371480472297911, 0.5649635036496351
        0.3460490463215259, 0.27445255474452557
        0.35463215258855585, 0.10802919708029202
        0.3638510445049955, 0.0627737226277374
        0.37306993642143504, 0.040875912408758985
        0.3829246139872843, 0.01897810218978102
        0.39309718437783836, 0.005839416058394331
        0.40040871934604905, 0.0014598540145984717
        0.40708446866485015, 0.0014598540145984717
        0.41534968210717527, 0
        0.4242506811989101, 0""" # q-r: q in nm^-1
m_r_up = """
        0.10317892824704815, 0.9255474452554744
        0.11335149863760219, 0.9021897810218977
        0.12225249772933697, 0.9781021897810218
        0.13083560399636696, 0.9795620437956204
        0.14100817438692098, 0.9795620437956204
        0.14959128065395094, 0.983941605839416
        0.159763851044505, 0.7270072992700729
        0.16866485013623977, 0.3255474452554745
        0.17756584922797458, 0.14598540145985406
        0.187102633969119, 0.11678832116788329
        0.1963215258855586, 0.08613138686131383
        0.2055404178019982, 0.04963503649635048
        0.2150772025431426, 0.039416058394160514
        0.2242960944595822, 0.037956204379562264
        0.2335149863760218, 0.02481751824817513
        0.24305177111716622, 0.021897810218978186
        0.25195277020890106, 0.020437956204379715
        0.2611716621253406, 0.014598540145985384
        0.27070844686648504, 0.014598540145985384
        0.2802452316076295, 0.01751824817518255
        0.2891462306993642, 0.01751824817518255
        0.29836512261580383, 0.011678832116788218
        0.30885558583106265, 0.011678832116788218
        """
m_r_dw = np.genfromtxt(StringIO(m_r_dw), delimiter=',', dtype=float)
m_r_up = np.genfromtxt(StringIO(m_r_up), delimiter=',', dtype=float)

fig, ax1 = plt.subplots()
Qc, Qc_Ni, Qmax = 0.0160, 0.0216, 0.03450
ax1.plot(m_r_dw[:,0]/10/Qc_Ni, m_r_dw[:,1], 'v', label='Spin down')
ax1.plot(m_r_up[:,0]/10/Qc_Ni, m_r_up[:,1], '^', label='Spin up')

Stdreflecfunc_plot(ax1, 0.99, Qc, 16.0, Qmax/Qc, 0.001, 0, 2, label='McStas\n'+r'Qc={:1.4f} $\alpha$={:4.1f} m=Q/Qc={:1.1f} w={:1.3f}'.format(Qc, 16.0, Qmax/Qc,0.001) ,ls='-')
Stdreflecfunc_plot(ax1, 0.99, Qc, 10.0, 1,       0.002, 0, 2, label='McStas\n'+r'Qc={:1.4f} $\alpha$={:5.1f} m=Q/Qc={:1.1f} w={:1.3f}'.format(Qc, 0, Qc/Qc, 0.002) ,ls='-')
#Stdreflecfunc_plot(ax1, 0.99, 0.0216, 2.6, 4.5, 0.001, 0, 5, label=r'SwissN. m={} $\alpha$={} EdgeWidth={}'.format(4.5,2.6, 1e-3) ,ls='-',zorder=1)
#ax1.set_xlim([0,6])
ax1.legend(handletextpad=0.5)
ax2 = ax1.twiny()
ax2.set_xticks(ax1.get_xticks())
ax2.set_xbound(ax1.get_xbound())
ax2.set_xticklabels([np.round(x*0.0216,decimals=4) for x in ax1.get_xticks()])
ax2.set_xlabel('$Q_\mathrm{z} (\mathrm{\AA}^{-1}$)')
ax2.grid(False)
plt.tight_layout(pad=5)
plt.show()

# %% [markdown]
# # +10% longer

# %%
L=0.05 # using
d=0.00013
R = L**2/(8*d)/1.21 # use a samller R

L_ = np.sqrt(8*d*R) # cal corresponding L of the smaller R
print('The L used is {:1.1f} times the required'.format(L/L_))

# %%
up, down = 25, 3
(up-down)/(up+down)

# %% [markdown]
# # With cold source

# %% [markdown]
# ## Overviews

# %%
path = r'D:\5_Instrument\Mira_Bender_coldS\lapis_ki1-3_noBender/10'
make_sub_plot(load_results(path))

# %%
plt.close('all')
path = r'D:\5_Instrument\Mira_Bender_coldS/lapis_ki1-3_benderL0p05_benderZ0p5_rmh0_3e6_absorb/10'
data = load_results(path)[8].metadata.info['component']
make_sub_plot(load_results(path))

#path = r'D:\5_Instrument\Mira_Bender_coldS\lapis_ki1-3_noBender_benderZ0p5_rmh0_1e8/10'
#make_sub_plot(load_results(path))

# %%
plt.close('all')

# %%
1296/4611
1316/4570
0.48/4.7
0.95/4.7
1.9/4.7
path = r'D:\5_Instrument\Mira_Bender_coldS/lapis_ki1-3_benderL0p04_benderZ0p5_rmh0_1e8_absorb/10'
(load_results(path)[15].Error**2).sum()**0.5

# %%
out = load_ki_scan(r'D:\5_Instrument\Mira_Bender_coldS/lapis_ki1-3_benderL0p03/')
#my_make_plot(out)
print(out[1].Intensity)
make_sub_plot(out)

# %% [markdown]
# ## Check lam dependent pol

# %%
plt.close('all')
path = r'D:\5_Instrument\Mira_Bender_coldS\with_2by6cm_Up_2by2cm_total_atSample/lapis_ki1-3_benderL0p03_1e8_absorb/0/'
#make_sub_plot(load_results(path))
path = r'D:\5_Instrument\Mira_Bender_coldS\with_2by6cm_Up_2by2cm_total_atSample/lapis_ki1-3_benderL0p03_benderZ0p5_rmh0_1e8_absorb/10/'
path = r'D:\5_Instrument\Mira_Bender_coldS\with_2by2cm_Up_benderZ0p5_rmh0_1e8_absorb/lapis_ki1-3_benderL0p03_benderZ0p5_rmh0_1e8_absorb/10/'

data = load_results(path)
#my_list = [data[idx] for idx in [5,7,9,10,11,12,13]]
my_list = [data[idx] for idx in [5,7,9,10,11,12,13]]
make_sub_plot(my_list)
# path = r'D:\5_Instrument\Mira_Bender_coldS\with_2by6cm_Up_2by2cm_total_atSample/lapis_ki1-3_noBender_1e8/9/'
# make_sub_plot(load_results(path))

# %% [markdown]
# ### Load into list varying bender length for a Ki

# %%
path = r'D:\5_Instrument\Mira_Bender_coldS\with_2by6cm_Up_2by2cm_total_atSample/'
pattern='lapis_ki1-3_benderL{}_1e8_absorb/10'
pattern = 'lapis_ki1-3_benderL{}_benderZ0p5_rmh0_1e8_absorb/0'
benderPar = np.linspace(0.03, 0.13,11, endpoint=True) # Bender parameters

pol = [None]*len(benderPar)
IU =  [None]*len(benderPar)
ID =  [None]*len(benderPar)
IhdivU =  [None]*len(benderPar)
IhdivD =  [None]*len(benderPar)

for idx, i in enumerate(benderPar):
    path0 = path + pattern.format(benderPar[idx]).replace('.','p')
    data = load_results(path0)
    pol[idx], IU[idx], ID[idx], IhdivU[idx], IhdivD[idx] = data[7],data[9],data[10],data[11],data[12]

# %% [markdown]
# ### Load into list varying Ki for a bender length

# %%
path = r'D:\5_Instrument\Mira_Bender_coldS\with_2by6cm_Up_2by2cm_total_atSample/'
pattern='lapis_ki1-3_benderL0p03_1e8_absorb/'

pol = [None]*len(benderPar)
IU =  [None]*len(benderPar)
ID =  [None]*len(benderPar)
IhdivU =  [None]*len(benderPar)
IhdivD =  [None]*len(benderPar)

for idx in range(11):
    path0 = path + pattern + str(idx)
    data = load_results(path0)
    pol[idx], IU[idx], ID[idx], IhdivU[idx], IhdivD[idx] = data[7],data[9],data[10],data[11],data[12]

# %%
def make_overplot(datalist, **kwargs):
    fig, ax = plt.subplots()
    for data in datalist:
        ax.errorbar(x=data.xaxis, y=data.Intensity, yerr=data.Error, **kwargs)
    return fig, ax

#make_overplot(pol[::2])
make_sub_plot(pol)

# %% [markdown]
# ### Check average pol calculation

# %%
path = r'D:\5_Instrument\Mira_Bender_coldS/'
pattern='lapis_ki1-3_benderL0p1_benderZ0p5_rmh0_3e6_absorb/'

path0 = path + pattern + str(0)
data = load_results(path0)
make_sub_plot(data)

#weight = data[7].Ncount/data[7].Ncount.sum()
weight = data[8].Intensity/data[8].Intensity.sum()
Intensity = (data[7].Intensity*weight).sum()
Error =  ((data[7].Error*weight)**2).sum()**0.5
print(Intensity, Error)

# %% [markdown]
# ## Plot pol, I

# %%
# Bender without absorb: scan L at Z=0.4
#pol_I1_I2_Isam1_Isam2 = load_bender_scan(path=r'D:\5_Instrument\Mira_Bender_coldS/', pattern='lapis_ki1-3_benderL{}/', start_end_nb = [0.03, 0.13, 11], idxs = [7, 3, 9, 16, 17])
#pol_I1_I2_Isam1_Isam2 = load_bender_scan(path=r'D:\5_Instrument\Mira_Bender_coldS/', pattern='lapis_ki1-3_benderL{}_1e8/', start_end_nb = [0.03, 0.13, 11], idxs = [7, 3, 9, 16, 17,15])

# Bender with absorb: scan L at Z=0.4
#pol_I1_I2_Isam1_Isam2_absorb  = load_bender_scan(path=r'D:\5_Instrument\Mira_Bender_coldS/', pattern='lapis_ki1-3_benderL{}_absorb/', start_end_nb = [0.03, 0.13, 11], idxs = [7, 3, 9, 16, 17])
#pol_I1_I2_Isam1_Isam2_absorb  = load_bender_scan(path=r'D:\5_Instrument\Mira_Bender_coldS/', pattern='lapis_ki1-3_benderL{}_1e8_absorb/', start_end_nb = [0.03, 0.13, 11], idxs = [7, 3, 9, 16, 17, 15])

# no Bender
#Isam1_Isam2_noB  = load_ki_scan(path=r'D:\5_Instrument\Mira_Bender_coldS\lapis_ki1-3_noBender/', start_end_nb = [1.0,3.2,11],  idxs = [14,15])  
#Isam1_Isam2_noB  = load_ki_scan(path=r'D:\5_Instrument\Mira_Bender_coldS\lapis_ki1-3_noBender_1e8/', start_end_nb = [1.0,3.2,11],  idxs = [14,15])  
Isam1_Isam2_noB  = load_ki_scan(path=r'D:\5_Instrument\Mira_Bender_coldS\lapis_ki1-3_noBender_benderZ0p5_rmh0_1e8/', start_end_nb = [1.0,3.2,11],  idxs = [14,15])

# %%
# Bender with absorb: scan Z at L=0.05， 1e7
pol_I1_I2_Isam1_Isam2_absorb_scanZ = load_bender_scan(path=r'D:\5_Instrument\Mira_Bender_coldS/with_2by6cm_Up_2by2cm_total_atSample/', 
                                                      pattern='lapis_ki1-3_benderL0p05_benderZ{:1.1f}_absorb/', start_end_nb = [0.2, 1.6, 8], idxs = [7, 3, 9, 16, 17])

# %%
### 130mum, Z=0.4, 1e7: scan L (small monitor at sample: total up and down intensity)
path = r'D:\5_Instrument\Mira_Bender_coldS\with_2by6cm_Up_2by2cm_total_atSample/'
# Bender without absorb:
#pol_I1_I2_Isam1_Isam2 = load_bender_scan(path=path, pattern='lapis_ki1-3_benderL{}/', start_end_nb = [0.03, 0.13, 11], idxs = [7, 3, 9, 16, 17])

# Bender with absorb: scan L
pol_I1_I2_Isam1_Isam2_absorb  = load_bender_scan(path=path, pattern='lapis_ki1-3_benderL{}_absorb/', start_end_nb = [0.03, 0.13, 11], idxs = [7, 3, 9, 16, 17])

# no Bender
Isam1_Isam2_noB  = load_ki_scan(path=path+r'\lapis_ki1-3_noBender/', start_end_nb = [1.0,3.2,11],  idxs = [14,15])  

# with absorb divided by noBender
*figsaxs, color = plot_scanL_scanKi(pol_I1_I2_Isam1_Isam2_absorb, start_end_nb = [0.03,0.13,11], idx_pol=0, idx_I_before=1, idx_I_after=2, idx_I_sample=[3,4], longer=1.1, noBenderI=Isam1_Isam2_noB[0])    
figs, axs = figsaxs[:int(len(figsaxs)/2)+1], figsaxs[int(len(figsaxs)/2):]

figs[0].set_size_inches(5, 4, forward=True)
figs[1].set_size_inches(5, 4, forward=True)
figs[2].set_size_inches(5, 4, forward=True)

# %%
### 130mum, Z=0.4, 1e8: scan L (small monitor at sample: 2by2cm total up and down intensity, 2by6cm up intensity)
path = r'D:\5_Instrument\Mira_Bender_coldS\with_2by6cm_Up_2by2cm_total_atSample/'

# Bender without absorb:
#pol_I1_I2_Isam1_Isam2 = load_bender_scan(path=path, pattern='lapis_ki1-3_benderL{}_1e8/', start_end_nb = [0.03, 0.13, 11], idxs = [7, 3, 9, 16, 17])

# Bender with absorb: scan L
pol_I1_I2_Isam1_Isam2_absorb  = load_bender_scan(path=path, pattern='lapis_ki1-3_benderL{}_1e8_absorb/', start_end_nb = [0.03, 0.13, 11], idxs = [7, 3, 9, 16, 17])

# no Bender
Isam1_Isam2_noB  = load_ki_scan(path=path+r'lapis_ki1-3_noBender_1e8/', start_end_nb = [1.0,3.2,11],  idxs = [14,15])  

# with absorb divided by noBender
*figsaxs, color = plot_scanL_scanKi(pol_I1_I2_Isam1_Isam2_absorb, start_end_nb = [0.03,0.13,11], idx_pol=0, idx_I_before=1, idx_I_after=2, idx_I_sample=[3,4], longer=1.1, noBenderI=Isam1_Isam2_noB[0])    
figs, axs = figsaxs[:int(len(figsaxs)/2)+1], figsaxs[int(len(figsaxs)/2):]

figs[0].set_size_inches(5, 4, forward=True)
figs[1].set_size_inches(5, 4, forward=True)
figs[2].set_size_inches(5, 4, forward=True)
#axs[0].set_ylim([0.7,1.05])
#axs[1].set_ylim([0.,0.5])
#axs[2].set_ylim([0.,0.8])

# %%
plt.close('all')

# %%
### 130mum, Z=0.5, RMH=0, 1e8: scan L
path = r'D:\5_Instrument\Mira_Bender_coldS/with_2by6cm_Up_2by2cm_total_atSample/'
# no Bender 
Isam1_Isam2_noB  = load_ki_scan(path=path+r'lapis_ki1-3_noBender_benderZ0p5_rmh0_1e8/', start_end_nb = [1.0,3.2,11],  idxs = [14,15])  

# Bender with absorption
pol_I1_I2_Isam1_Isam2_absorb = load_bender_scan(path=path, pattern='lapis_ki1-3_benderL{}_benderZ0p5_rmh0_1e8_absorb/', start_end_nb = [0.03, 0.13, 11], idxs = [7, 3, 9, 16, 17])

# with absorb divided by noBender
*figsaxs, color = plot_scanL_scanKi(pol_I1_I2_Isam1_Isam2_absorb, start_end_nb = [0.03,0.13,11], idx_pol=0, idx_I_before=1, idx_I_after=2, idx_I_sample=[3,4,5], longer=1.1, noBenderI=Isam1_Isam2_noB[0])    
figs, axs = figsaxs[:int(len(figsaxs)/2)+1], figsaxs[int(len(figsaxs)/2):]

figs[0].set_size_inches(5, 4, forward=True)
figs[1].set_size_inches(5, 4, forward=True)
figs[2].set_size_inches(5, 4, forward=True)
axs[0].set_ylim([0.7,1.05])
axs[1].set_ylim([0.,0.5])
axs[2].set_ylim([0.,0.5])

# %%
longer, d = 1.1, 0.000130
Ls = np.linspace(0.03,0.13, num=11, endpoint=True) # bender length
Rs = (Ls**2 /8/d)/longer # bender radius
#Ac = Ls/(2*Rs) # critical angle
Ac = np.sqrt(2*d/Rs)# use this one for calculating Lmabda_c if bender is longer than the exact value for avoiding direct view
Lc = Ac/(1.73*3.6)*1e3 # critical lambda
Angle = -Ls/Rs*180/3.1415926 # bender arc angle
print(Angle)

# %%
19.83/4

# %%
### 130mum, Z=0.5, RMH=0, 1e8: scan L
longer, d = 1.1, 0.000130
Ls = np.linspace(0.03,0.13, num=11, endpoint=True) # bender length
Rs = (Ls**2 /8/d)/longer # bender radius
#Ac = Ls/(2*Rs) # critical angle
Ac = np.sqrt(2*d/Rs)# use this one for calculating Lmabda_c if bender is longer than the exact value for avoiding direct view
Lc = Ac/(1.73*3.6)*1e3 # critical lambda
Angle = -Ls/Rs*180/3.1415926 # bender arc angle

path = r'D:\5_Instrument\Mira_Bender_coldS\with_2by2cm_Up_benderZ0p5_rmh0_1e8_absorb/'
pattern='lapis_ki1-3_benderL{}_benderZ0p5_rmh0_1e8_absorb/'
# no Bender 
Isam1_Isam2_noB  = load_ki_scan(path=path + r'lapis_ki1-3_noBender_benderZ0p5_rmh0_1e8/', start_end_nb = [1.0,3.2,11],  idxs = [14,15]) # (2X2cm and 10X20cm monitors @sample) 

# Bender with absorption
pol_I1_I2_Isam1_Isam2 = load_bender_scan(path=path, pattern=pattern, 
                                         start_end_nb = [0.03, 0.13, 11], idxs = [7, 3, 9, 15, 16, 17]) # pol, Ibefore, Iafter, IsampleU, IsampleD, IsampleUD (2X2cm monitors @sample)

#make_sub_plot(load_results(path + r'lapis_ki1-3_noBender_benderZ0p5_rmh0_1e8/'+'0/'))
#make_sub_plot(load_results(path+pattern.format(0.05).replace('.','p')+'0/'))

# with absorb divided by noBender
*figsaxs, color = plot_scanL_scanKi(pol_I1_I2_Isam1_Isam2_absorb, start_end_nb = [0.03,0.13,11], idx_pol=0, idx_I_before=1, idx_I_after=2, idx_I_sample=[3,4], longer=1.1, noBenderI=Isam1_Isam2_noB[0])    
figs, axs = figsaxs[:int(len(figsaxs)/2)+1], figsaxs[int(len(figsaxs)/2):]

figs[0].set_size_inches(5, 4, forward=True)
figs[1].set_size_inches(5, 4, forward=True)
figs[2].set_size_inches(5, 4, forward=True)
axs[0].set_ylim([0.7,1.05])
axs[1].set_ylim([0.,0.5])
#axs[2].set_ylim([0.,0.8])

# %%
### 150mum, Z=0.5, RMH=0, 1e8: scan L
longer, d = 1.1, 0.000150
Ls = np.linspace(0.03,0.13, num=11, endpoint=True) # bender length
Rs = (Ls**2 /8/d)/longer # bender radius
#Ac = Ls/(2*Rs) # critical angle
Ac = np.sqrt(2*d/Rs)# use this one for calculating Lmabda_c if bender is longer than the exact value for avoiding direct view
Lc = Ac/(1.73*3.6)*1e3 # critical lambda
Angle = -Ls/Rs*180/3.1415926 # bender arc angle

path = r'D:\5_Instrument\Mira_Bender_coldS\with_2by2cm_Up_benderZ0p5_rmh0_1e8_absorb/'
# no Bender 
Isam1_Isam2_noB  = load_ki_scan(path=path + r'lapis_ki1-3_noBender_benderZ0p5_rmh0_1e8/', start_end_nb = [1.0,3.2,11],  idxs = [14,15])  # (2X2cm and 10X20cm monitors @sample) 

# Bender with absorption
pol_I1_I2_Isam1_Isam2 = load_bender_scan(path=path, pattern='lapis150mum_ki1-3_benderL{}_benderZ0p5_rmh0_1e8_absorb/', 
                                         start_end_nb = [0.03, 0.13, 11], idxs = [7, 3, 9, 16, 17,15])  # pol, Ibefore, Iafter, IsampleU, IsampleD, IsampleUD (2X2cm monitors @sample)

# with absorb divided by noBender
*figsaxs, color = plot_scanL_scanKi(pol_I1_I2_Isam1_Isam2_absorb, start_end_nb = [0.03,0.13,11], d=0.000150, idx_pol=0, idx_I_before=1, idx_I_after=2, idx_I_sample=[3,4], longer=1.1, noBenderI=Isam1_Isam2_noB[0])    
figs, axs = figsaxs[:int(len(figsaxs)/2)+1], figsaxs[int(len(figsaxs)/2):]

figs[0].set_size_inches(5, 4, forward=True)
figs[1].set_size_inches(5, 4, forward=True)
figs[2].set_size_inches(5, 4, forward=True)
axs[0].set_ylim([0.7,1.05])
axs[1].set_ylim([0.,0.5])
axs[2].set_ylim([0.,0.5])

# %%
### 200mum, Z=0.5, RMH=0, 1e8: scan L
longer, d = 1.1, 0.000200
Ls = np.linspace(0.03,0.13, num=11, endpoint=True) # bender length
Rs = (Ls**2 /8/d)/longer # bender radius
#Ac = Ls/(2*Rs) # critical angle
Ac = np.sqrt(2*d/Rs)# use this one for calculating Lmabda_c if bender is longer than the exact value for avoiding direct view
Lc = Ac/(1.73*3.6)*1e3 # critical lambda
Angle = -Ls/Rs*180/3.1415926 # bender arc angle

path = r'D:\5_Instrument\Mira_Bender_coldS\with_2by2cm_Up_benderZ0p5_rmh0_1e8_absorb/'
# no Bender 
Isam1_Isam2_noB  = load_ki_scan(path=path + r'lapis_ki1-3_noBender_benderZ0p5_rmh0_1e8/', start_end_nb = [1.0,3.2,11],  idxs = [14,15])  

# Bender with absorption
pol_I1_I2_Isam1_Isam2 = load_bender_scan(path=path, pattern='lapis200mum_ki1-3_benderL{}_benderZ0p5_rmh0_1e8_absorb/', start_end_nb = [0.03, 0.13, 11], idxs = [7, 3, 9, 16, 17,15])

# with absorb divided by noBender
*figsaxs, color = plot_scanL_scanKi(pol_I1_I2_Isam1_Isam2_absorb, start_end_nb = [0.03,0.13,11],d=0.000200, idx_pol=0, idx_I_before=1, idx_I_after=2, idx_I_sample=[3,4], longer=1.1, noBenderI=Isam1_Isam2_noB[0])    
figs, axs = figsaxs[:int(len(figsaxs)/2)+1], figsaxs[int(len(figsaxs)/2):]

figs[0].set_size_inches(5, 4, forward=True)
figs[1].set_size_inches(5, 4, forward=True)
figs[2].set_size_inches(5, 4, forward=True)
axs[0].set_ylim([0.7,1.05])
axs[1].set_ylim([0.,0.5])
axs[2].set_ylim([0.,0.5])

# %%
plt.close('all')

# %%
# Plot Bender_Z scan (first modifying the plot function definition)
*figsaxs, color = plot_scanL_scanKi(pol_I1_I2_Isam1_Isam2_absorb_scanZ, start_end_nb = [0.2,1.6,8], idx_pol=0, idx_I_before=1, idx_I_after=2, idx_I_sample=[3,4], longer=1.1, noBenderI=Isam1_Isam2_noB[0])    
figs, axs = figsaxs[:int(len(figsaxs)/2)+1], figsaxs[int(len(figsaxs)/2):]

figs[0].set_size_inches(5, 4, forward=True)
figs[1].set_size_inches(5, 4, forward=True)
figs[2].set_size_inches(5, 4, forward=True)
axs[0].set_ylim([0.8,1.05])
axs[1].set_ylim([0.,0.5])
axs[2].set_ylim([0.,0.5])

# %% [markdown]
# # Plot

# %%
plt.close('all')

# without absorb divided by large monitor at sample position
# *figsaxs, color = plot_scanL_scanKi(pol_I1_I2_Isam1_Isam2, start_end_nb = [0.03,0.13,11], idx_pol=0, idx_I_before=1, idx_I_after=2, idx_I_sample=[3,4], longer=1.1, noBenderI=None)    
# figs, axs = figsaxs[:int(len(figsaxs)/2)+1], figsaxs[int(len(figsaxs)/2):]

# figs[0].set_size_inches(5, 4, forward=True)
# figs[1].set_size_inches(5, 4, forward=True)
# figs[2].set_size_inches(5, 4, forward=True)
# axs[0].set_ylim([0.7,1.05])
# axs[1].set_ylim([0.,0.5])
# axs[2].set_ylim([0.,0.8])

# with absorb divided by large monitor at sample position
# *figsaxs, color = plot_scanL_scanKi(pol_I1_I2_Isam1_Isam2_absorb, start_end_nb = [0.03,0.13,11], idx_pol=0, idx_I_before=1, idx_I_after=2, idx_I_sample=[3,4], longer=1.1, noBenderI=None)    
# figs, axs = figsaxs[:int(len(figsaxs)/2)+1], figsaxs[int(len(figsaxs)/2):]

# figs[0].set_size_inches(5, 4, forward=True)
# figs[1].set_size_inches(5, 4, forward=True)
# figs[2].set_size_inches(5, 4, forward=True)
# axs[0].set_ylim([0.7,1.05])
# axs[1].set_ylim([0.,0.5])
# axs[2].set_ylim([0.,0.8])

# without absorb divided by noBender
# *figsaxs, color = plot_scanL_scanKi(pol_I1_I2_Isam1_Isam2, start_end_nb = [0.03,0.13,11], idx_pol=0, idx_I_before=1, idx_I_after=2, idx_I_sample=[5,4], longer=1.1, noBenderI=Isam1_Isam2_noB[0])    
# figs, axs = figsaxs[:int(len(figsaxs)/2)+1], figsaxs[int(len(figsaxs)/2):]

# figs[0].set_size_inches(5, 4, forward=True)
# figs[1].set_size_inches(5, 4, forward=True)
# figs[2].set_size_inches(5, 4, forward=True)
# axs[0].set_ylim([0.7,1.05])
# axs[1].set_ylim([0.,0.5])
# axs[2].set_ylim([0.,0.8])

# with absorb divided by noBender
*figsaxs, color = plot_scanL_scanKi(pol_I1_I2_Isam1_Isam2_absorb, start_end_nb = [0.03,0.13,11], idx_pol=0, idx_I_before=1, idx_I_after=2, idx_I_sample=[3,4], longer=1.1, noBenderI=Isam1_Isam2_noB[0])    
figs, axs = figsaxs[:int(len(figsaxs)/2)+1], figsaxs[int(len(figsaxs)/2):]

figs[0].set_size_inches(5, 4, forward=True)
figs[1].set_size_inches(5, 4, forward=True)
figs[2].set_size_inches(5, 4, forward=True)
axs[0].set_ylim([0.7,1.05])
axs[1].set_ylim([0.,0.5])
axs[2].set_ylim([0.,0.8])

# %%
def load_ki_scan(path, start_end_nb = [1.0,3.2,11], idxs = [7, 3, 9, 15, 16, 17]):  
    #pol=7, I_before=3, I_after=9, I_sample=16, I_sample_big=17  
    scan =[]    
    for i in range(start_end_nb[2]):
        scan.append(load_results(path+str(i)+'/'))
    
    x, y, e = np.zeros(start_end_nb[2]), np.zeros(start_end_nb[2]), np.zeros(start_end_nb[2])
    
    out = [None]*len(idxs)
    for ind, i in enumerate(idxs):
        out[ind] = scan[0][i]
        for idx, sim in enumerate(scan):
            mid = np.shape(sim[i].xaxis)[0]//2
            
            #if out[ind].metadata.info["component"] != "meanpollambdaMonitorY_bender":
            #    print(out[ind].metadata.info["component"])
            #    start, end = mid-20, mid+20 # average several points
            #else: 
            #    start, end = mid, mid+1 # average several points
            #    print('pol: averge 1 points')
            #x[idx], y[idx], e[idx] = sim[i].xaxis[mid], sim[i].Intensity[start:end].sum(), (sim[i].Error[start:end]**2).mean()**0.5
            
            if out[ind].metadata.info["component"] != 'meanpollambdaMonitorY_bender\n':
                #print(out[ind].metadata.info["component"])
                x[idx], y[idx], e[idx] = sim[i].xaxis[mid], sim[i].Intensity.sum(), (sim[i].Error**2).sum()**0.5
            else: 
                #print(out[ind].metadata.info["component"])
                #x[idx], y[idx], e[idx] = sim[i].xaxis[mid], sim[i].Intensity[mid], sim[i].Error[mid]
                weight = sim[i+1].Intensity/sim[i+1].Intensity.sum() # assuming the next monitor is a L_monitor
                Intensity = (sim[i].Intensity*weight).sum()
                Error =  ((sim[i].Error*weight)**2).sum()**0.5
                x[idx], y[idx], e[idx] = sim[i].xaxis[mid], Intensity, Error
                
        out[ind].xaxis, out[ind].Intensity, out[ind].Error = x.copy(), y.copy(), e.copy()
        out[ind].metadata.limits = [2*np.pi/start_end_nb[1], 2*np.pi/start_end_nb[0]]
    return out
    
def load_bender_scan(path=r'D:\5_Instrument\Mira_Bender_coldS/', pattern='lapis_ki1-3_bender{}/', start_end_nb = [0.03, 0.13, 11], idxs = [7, 3, 9, 16, 17, 15]):
    
    benderPar = np.linspace(start_end_nb[0], start_end_nb[1], num=start_end_nb[2], endpoint=True) # Bender parameters
    print(benderPar)
    scan = []
    
    for i in range(start_end_nb[2]):
        path0 = path + pattern.format(benderPar[i]).replace('.','p')
        print(path0)
        #ki_scan = load_ki_scan(path0, start_end_nb = [1.0,3.2,11], pol=7, I_before=3, I_after=9, I_sample=16, I_sample_big=17)
        ki_scan = load_ki_scan(path0, start_end_nb = [1.0,3.2,11], idxs =idxs)
        scan.append(ki_scan)
    return scan

def plot_scanL_scanKi(Scan, start_end_nb = [0.03,0.13,10], d=0.000130, idx_pol=0, idx_I_before=1, idx_I_after=2, idx_I_sample=[3,4], longer=1.1, noBenderI=None):
    import copy
    
    param = np.linspace(start_end_nb[0], start_end_nb[1], start_end_nb[2], endpoint=True) # Bender lengths
    color = cm.get_cmap('jet')((param-param[0])/(param[-1]-param[0]))
    nS = np.ceil(0.06/d)
    
    # plot P vs lambda
    for i in range(len(param)):
        if i==0:
            fig0, ax0 = my_make_plot(Scan[i][idx_pol], c=color[i], label='L=%1.3f m,'%param[i]  +  r' R$_{calc}=$%1.1f' % (param[i]**2/8/d/longer) )
        else:
            ax0.errorbar(Scan[i][idx_pol].xaxis, Scan[i][idx_pol].Intensity, yerr=Scan[i][idx_pol].Error, c=color[i], 
                         label='L=%1.3f'%param[i]+' m,'  +  ' R$_{calc}=$%1.1f' % (param[i]**2/8/d/longer) )
    #plt.legend(title='nSlits=%d'%nS)
    #plt.ylim([0.995,1.001])

    # plot I vs Lambda
    for i in range(len(param)):
        if i==0:
            temp = copy.deepcopy(Scan[i][idx_I_after]) # avoid changing the orginal obj
            fig1, ax1 = my_make_plot(temp/Scan[i][idx_I_before],
                                     c=color[i], label='L=%1.3f m,' % param[i]  +  r' R$_{calc}=$%1.1f' % (param[i]**2/8/d/longer) )
        else:
            ax1.errorbar(x =  Scan[i][idx_I_after].xaxis, 
                         y =  Scan[i][idx_I_after].Intensity/Scan[i][idx_I_before].Intensity, 
                         yerr=Scan[i][idx_I_after].Error    /Scan[i][idx_I_before].Intensity,
                         c=color[i], 
                         label='L=%1.3f'%param[i]+' m,'  +  r' R$_{calc}=$%1.1f' % (param[i]**2/8/d/longer))
    plt.legend(title='nSlits=%d'%nS)

    # plot I/I at sample position
    if idx_I_sample != None:
        for i in range(len(param)):
            if i==0:
                temp = copy.deepcopy(Scan[i][idx_I_sample[0]]) # avoid changing the orginal obj
                
                if noBenderI != None: # use noBender sample intensity 
                    temp1 = noBenderI
                    print('\n*****Used noBender reference*****\n')
                else:
                    temp1 = Scan[i][idx_I_sample[1]] # use large monitor at sample with bender
                    
                fig2, ax2 = my_make_plot(temp/temp1,
                                         c=color[i], label='L=%1.3f m,' % param[i]  +  r' R$_{calc}=$%1.1f' % (param[i]**2/8/d/longer) )
            else:
                ax2.errorbar(x =  Scan[i][idx_I_sample[0]].xaxis, 
                             y =  Scan[i][idx_I_sample[0]].Intensity/temp1.Intensity, 
                             yerr= ( (Scan[i][idx_I_sample[0]].Error/temp1.Intensity)**2 + (Scan[i][idx_I_sample[0]].Intensity/temp1.Intensity**2*temp1.Error)**2 )**0.5,
                             c=color[i], 
                             label='L=%1.3f'%param[i]+' m,'  +  r' R$_{calc}=$%1.1f' % (param[i]**2/8/d/longer))
#     For plot scanning Z (legend is changed)              
#     if idx_I_sample != None:
#         for i in range(len(param)):
#             if i==0:
#                 temp = copy.deepcopy(Scan[i][idx_I_sample[0]]) # avoid changing the orginal obj
                
#                 if noBenderI != None: # use noBender sample intensity 
#                     temp1 = noBenderI 
#                 else:
#                     temp1 = Scan[i][idx_I_sample[1]] # use large monitor at sample with bender
                    
#                 fig2, ax2 = my_make_plot(temp/temp1,
#                                          c=color[i], label='Z=%1.3f m,' % param[i])
#             else:
#                 ax2.errorbar(x =  Scan[i][idx_I_sample[0]].xaxis, 
#                              y =  Scan[i][idx_I_sample[0]].Intensity/temp1.Intensity, 
#                              yerr=Scan[i][idx_I_sample[0]].Error    /temp1.Intensity,
#                              c=color[i], 
#                              label='Z=%1.3f'%param[i]+' m,' )
    plt.legend(title='nSlits=%d'%nS)
    return fig0, fig1, fig2, ax0, ax1, ax2, color

# %%
0.06/0.000150

# %% [markdown]
# # Define functions (from McstasScrpt)

# %% [markdown]
# ## Data class

# %%
#https://github.com/PaNOSC-ViNYL/McStasScript/blob/a7aa6703a0a27b387cecdb74c495a45290be80a6/mcstasscript/data/data.py
class McStasMetaData:
    """
    Class for holding metadata for McStas dataset, is to be read from
    mccode.sim file.
    Attributes
    ----------
    info : dict
        Contains read strings from mccode.sim in key, value
    dimension : Int or List of Int
        Int for 1d data set with lenght of data, Array for 2d with each
        length
    component_name : str
        Name of component in McStas file
    filename : str
        Name of data file to read
    limits : List
        Limits for monitor, length=2 for 1d data and length=4 for 2d
        data
    title : str
        Title of monitor when plotting
    xlabel : str
        Text for xlabel when plotting
    ylabel : str
        Text for ylabel when plotting
    Methods
    -------
    add_info(key,value)
        Adds a element to the info dictionary
    extract_info()
        Unpacks the information in info to class attributes
    set_title(string)
        Overwrites current title
    set_xlabel(string)
        Overwrites current xlabel
    set_ylabel(string)
        Overwrites current ylabel
    """

    def __init__(self):
        """Creating a new instance, no parameters"""
        self.info = {}

    def add_info(self, key, value):
        """Adding information to info dict"""
        self.info[key] = value

    def extract_info(self):
        """Extracting information from info dict to class attributes"""

        # Extract dimension
        if "type" in self.info:
            type_data = self.info["type"]
            if "array_1d" in type_data:
                type_data = type_data.split("(")[1]
                type_data = type_data.split(")")[0]
                self.dimension = int(type_data)
            if "array_2d" in type_data:
                self.dimension = []
                type_string1 = type_data.split(",")[0]
                type_string1 = type_string1.split("(")[1]
                self.dimension.append(int(type_string1))

                type_string2 = type_data.split(",")[1]
                type_string2 = type_string2.split(")")[0]
                self.dimension.append(int(type_string2))
        else:
            raise NameError("No type in mccode data section!")

        # Extract component name
        if "component" in self.info:
            self.component_name = self.info["component"].rstrip()

        # Extract filename
        if "filename" in self.info:
            self.filename = self.info["filename"].rstrip()
        else:
            # Monitors without output files does exist
            #raise NameError(
            #    "No filename found in mccode data section!")
            print("The component named \"" + self.component_name
                  + "\" had no data file and will not be loaded.")
            self.filename = ""

        # Extract limits
        self.limits = []
        if "xylimits" in self.info:
            # find the four numbers
            temp_str = self.info["xylimits"]
            limits_string = temp_str.split()
            for limit in limits_string:
                self.limits.append(float(limit))

        if "xlimits" in self.info:
            # find the two numbers
            temp_str = self.info["xlimits"]
            limits_string = temp_str.split()
            for limit in limits_string:
                self.limits.append(float(limit))

        # Extract plotting labels and title
        if "xlabel" in self.info:
            self.xlabel = self.info["xlabel"].rstrip()
        if "ylabel" in self.info:
            self.ylabel = self.info["ylabel"].rstrip()
        if "title" in self.info:
            self.title = self.info["title"].rstrip()

    def set_title(self, string):
        """Sets title for plotting"""
        self.title = string

    def set_xlabel(self, string):
        """Sets xlabel for plotting"""
        self.xlabel = string

    def set_ylabel(self, string):
        """Sets ylabel for plotting"""
        self.ylabel = string


class McStasPlotOptions:
    """
    Class that holds plotting options related to McStas data set
    Attributes
    ----------
    log : bool
        To plot on logarithmic or not, standard is linear
    orders_of_mag : float
        If plotting on log scale, restrict max range to orders_of_mag
        below maximum value
    colormap : string
        Chosen colormap for 2d data, should be available in matplotlib
    Methods
    -------
    set_options(keyword arguments)
        Can set the class attributes using keyword options
    """

    def __init__(self, *args, **kwargs):
        """Setting default values for plotting preferences"""
        self.log = False
        self.orders_of_mag = 300
        self.colormap = "viridis"
        self.show_colorbar = True
        self.cut_max = 1
        self.cut_min = 0
        self.x_limit_multiplier = 1
        self.y_limit_multiplier = 1
        
        self.custom_ylim_top = False
        self.custom_ylim_bottom = False
        self.custom_xlim_left = False
        self.custom_xlim_right = False

    def set_options(self, **kwargs):
        """Set custom values for plotting preferences"""
        if "log" in kwargs:
            log_input = kwargs["log"]
            if type(log_input) == int:
                if log_input == 0:
                    self.log = False
                else:
                    self.log = True
            elif type(log_input) == bool:
                self.log = log_input
            else:
                raise NameError(
                    "Log input must be either Int or Bool.")

        if "orders_of_mag" in kwargs:
            self.orders_of_mag = kwargs["orders_of_mag"]

        if "colormap" in kwargs:
            self.colormap = kwargs["colormap"]
            
        if "show_colorbar" in kwargs:
            self.show_colorbar = kwargs["show_colorbar"]
            
        if "cut_max" in kwargs:
            self.cut_max = kwargs["cut_max"]
            
        if "cut_min" in kwargs:
            self.cut_min = kwargs["cut_min"]
            
        if "x_axis_multiplier" in kwargs:
            self.x_limit_multiplier = kwargs["x_axis_multiplier"]
        
        if "y_axis_multiplier" in kwargs:
            self.y_limit_multiplier = kwargs["y_axis_multiplier"]
            
        if "top_lim" in kwargs:
            self.top_lim = kwargs["top_lim"]
            self.custom_ylim_top = True
            
        if "bottom_lim" in kwargs:
            self.bottom_lim = kwargs["bottom_lim"]
            self.custom_ylim_bottom = True
            
        if "left_lim" in kwargs:
            self.left_lim = kwargs["left_lim"]
            self.custom_xlim_left = True
            
        if "right_lim" in kwargs:
            self.right_lim = kwargs["right_lim"]
            self.custom_xlim_right = True
            


class McStasData:
    """
    Class for holding full McStas dataset with data, metadata and
    plotting preferences
    Attributes
    ----------
    metadata : McStasMetaData instance
        Holds the metadata for the dataset
    name : str
        Name of component, extracted from metadata
    Intensity : numpy array
        Intensity data [n/s] in 1d or 2d numpy array, dimension in
        metadata
    Error : numpy array
        Error data [n/s] in 1d or 2d numpy array, same dimensions as
        Intensity
    Ncount : numpy array
        Number of rays in bin, 1d or 2d numpy array, same dimensions as
        Intensity
    plot_options : McStasPlotOptions instance
        Holds the plotting preferences for the dataset
    Methods
    -------
    set_xlabel : string
        sets xlabel of data for plotting
    set_ylabel : string
        sets ylabel of data for plotting
    set_title : string
        sets title of data for plotting
    set_optons : keyword arguments
        sets plot options, keywords passed to McStasPlotOptions method
    """

    def __init__(self, metadata, intensity, error, ncount, **kwargs):
        """
        Initialize a new McStas dataset, 4 positional arguments, pass
        xaxis as kwarg if 1d data
        Parameters
        ----------
        metadata : McStasMetaData instance
            Holds the metadata for the dataset
        name : str
            Name of component, extracted from metadata
        intensity : numpy array
            Intensity data [n/s] in 1d or 2d numpy array, dimension in
            metadata
        error : numpy array
            Error data [n/s] in 1d or 2d numpy array, same dimensions
            as Intensity
        ncount : numpy array
            Number of rays in bin, 1d or 2d numpy array, same
            dimensions as Intensity
        kwargs : keyword arguments
            xaxis is required for 1d data
        """

        # attatch meta data
        self.metadata = metadata
        # get name from metadata
        self.name = self.metadata.component_name
        # three basic arrays from positional arguments
        self.Intensity = intensity
        self.Error = error
        self.Ncount = ncount

        if type(self.metadata.dimension) == int:
            if "xaxis" in kwargs:
                self.xaxis = kwargs["xaxis"]
            else:
                raise NameError(
                    "ERROR: Initialization of McStasData done with 1d "
                    + "data, but without xaxis for " + self.name + "!")

        self.plot_options = McStasPlotOptions()

    # Methods xlabel, ylabel and title as they might not be found
    def set_xlabel(self, string):
        self.metadata.set_xlabel(string)

    def set_ylabel(self, string):
        self.metadata.set_ylabel(string)

    def set_title(self, string):
        self.metadata.set_title(string, fontsize=10)

    def set_plot_options(self, **kwargs):
        self.plot_options.set_options(**kwargs)
        
    def __truediv__(self, other):# By Xu: for dividing
        if isinstance(other, McStasData):
            #self.Intensity, self.Error = self.Intensity/other.Intensity, self.Error/other.Intensity
            self.Intensity, self.Error = self.Intensity/other.Intensity, ( (self.Error/other.Intensity)**2 + (self.Intensity/other.Intensity**2*other.Error)**2 )**0.5
        else:
            self.Intensity, self.Error = self.Intensity / other, self.Error / other
        return self
    
    def __str__(self):
        """
        Returns string with quick summary of data
        """

        string = "McStasData: "
        string += self.name + " "
        if type(self.metadata.dimension) == int:
            string += "type: 1D "
        elif len(self.metadata.dimension) == 2:
            string += "type: 2D "
        else:
            string += "type: other "

        if "values" in self.metadata.info:
            values = self.metadata.info["values"]
            values = values.strip()
            values = values.split(" ")
            if len(values) == 3:
                string += " I:" + str(values[0])
                string += " E:" + str(values[1])
                string += " N:" + str(values[2])

        return string

    def __repr__(self):
        return "\n" + self.__str__()

# %% [markdown]
# ## Load_results

# %%
# https://github.com/PaNOSC-ViNYL/McStasScript/blob/a7aa6703a0a27b387cecdb74c495a45290be80a6/mcstasscript/helper/managed_mcrun.py
import os
import numpy as np
def load_results(data_folder_name):

#     if len(args) == 0:
#         data_folder_name = self.data_folder_name
#     elif len(args) == 1:
#         data_folder_name = args[0]
#     else:
#         raise InputError("load_results can be called with 0 or 1 arguments")

    if not os.path.isdir(data_folder_name):
        raise NameError("Given data directory does not exist.")

    # Find all data files in generated folder
    files_in_folder = os.listdir(data_folder_name)

    # Raise an error if mccode.sim is not available
    if "mccode.sim" not in files_in_folder:
        raise NameError("No mccode.sim in data folder.")

    # Open mccode to read metadata for all datasets written to disk
    f = open(os.path.join(data_folder_name, "mccode.sim"), "r")

    # Loop that reads mccode.sim sections
    metadata_list = []
    in_data = False
    for lines in f:
        # Could read other details about run

        if lines == "end data\n":
            # No more data for this metadata object
            # Extract the information
            current_object.extract_info()
            # Add to metadata list
            if current_object.filename != "":
                metadata_list.append(current_object)
            # Stop reading data
            in_data = False

        if in_data:
            # This line contains info to be added to metadata
            colon_index = lines.index(":")
            key = lines[2:colon_index]
            value = lines[colon_index+2:]
            current_object.add_info(key, value)

        if lines == "begin data\n":
            # Found data section, create new metadata object
            current_object = McStasMetaData()
            # Start recording data to metadata object
            in_data = True

    # Close mccode.sim
    f.close()
    for metadata in metadata_list: # Xu
        metadata.title += ': \n'+metadata.filename
        
    # Create a list for McStasData instances to return
    results = []

    # Load datasets described in metadata list individually
    for metadata in metadata_list:
        # Load data with numpy
        data = np.loadtxt(os.path.join(data_folder_name,
                          metadata.filename.rstrip()))

        # Split data into intensity, error and ncount
        if type(metadata.dimension) == int:
            xaxis = data.T[0, :]
            Intensity = data.T[1, :]
            Error = data.T[2, :]
            Ncount = data.T[3, :]

        elif len(metadata.dimension) == 2:
            xaxis = []  # Assume evenly binned in 2d
            data_lines = metadata.dimension[1]

            Intensity = data[0:data_lines, :]
            Error = data[data_lines:2*data_lines, :]
            Ncount = data[2*data_lines:3*data_lines, :]
        else:
            raise NameError(
                "Dimension not read correctly in data set "
                + "connected to monitor named "
                + metadata.component_name)

        # The data is saved as a McStasData object
        result = McStasData(metadata, Intensity,
                            Error, Ncount,
                            xaxis=xaxis)

        # Add this result to the results list
        results.append(result)

        # Close the current datafile
        f.close()

    # Return list of McStasData objects
    return results

# %% [markdown]
# ## Plot

# %%
# https://github.com/PaNOSC-ViNYL/McStasScript/blob/a7aa6703a0a27b387cecdb74c495a45290be80a6/mcstasscript/interface/plotter.py
import math
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator

def my_make_plot(data_list, **kwargs):
    """
    make_plot plots contents of McStasData objects
    Plotting is controlled through options assosciated with the
    McStasData objects.
    If a list is given, the plots appear individually.
    """

    #def __init__(self, data_list, **kwargs):
    """
    plots McStasData, single object or list of McStasData
    The options concerning plotting are stored with the data
    Parameters
    ----------
    data_list : McStasData or list of McStasData
        McStasData to be plotted
    """

    # Relevant options:
    #  select colormap
    #  show / hide colorbar
    #  custom title / label
    #  color of 1d plot
    #  overlay several 1d
    #  log scale (orders of magnitude)
    #  compare several 1d
    #  compare 2D

    if isinstance(data_list, McStasData):
        # Only a single element, put it in a list for easier syntax later
        data_list = [data_list]

    number_of_plots = len(data_list)

    if "fontsize" in kwargs:
        plt.rcParams.update({'font.size': kwargs["fontsize"]})
    if 'label' in kwargs:
        label = kwargs['label']
        
    print("number of elements in data list = " + str(len(data_list)))

    index = -1
    figs, axs = [], []
    for data in data_list:
        index = index + 1

        print("Plotting data with name " + data.metadata.component_name)
        if type(data.metadata.dimension) == int:
            fig, (ax0) = plt.subplots()

            x_axis_mult = data.plot_options.x_limit_multiplier
            #print(data.__dict__)
            x = data.xaxis*x_axis_mult
            y = data.Intensity
            y_err = data.Error
            try:
                #ax0.errorbar(x, y, yerr=y_err, c=kwargs['c'], label=kwargs['label'])
                ax0.errorbar(x, y, yerr=y_err, **kwargs)
            except:
                ax0.errorbar(x, y, yerr=y_err)
                
            if data.plot_options.log:
                ax0.set_yscale("log", nonposy='clip')

            ax0.set_xlim(data.metadata.limits[0]*x_axis_mult,
                         data.metadata.limits[1]*x_axis_mult)

            # Add a title
            plt.title(data.metadata.title, fontsize=10)

            # Add axis labels
            plt.xlabel(data.metadata.xlabel)
            plt.ylabel(data.metadata.ylabel)

            if data.plot_options.custom_xlim_left:
                ax0.set_xlim(left=data.plot_options.left_lim)

            if data.plot_options.custom_xlim_right:
                ax0.set_xlim(right=data.plot_options.right_lim)
            figs.append(fig)
            axs.append(ax0)
            
        elif len(data.metadata.dimension) == 2:
            # Split the data into intensity, error and ncount
            Intensity = data.Intensity
            Error = data.Error
            Ncount = data.Ncount

            cut_max = data.plot_options.cut_max  # Default 1
            cut_min = data.plot_options.cut_min  # Default 0

            if data.plot_options.log:
                to_plot = Intensity

                max_data_value = to_plot.max()

                min_value = np.min(Intensity[np.nonzero(Intensity)])
                min_value = np.log10(min_value
                                     + (max_data_value-min_value)*cut_min)

                max_value = np.log10(max_data_value*cut_max)

                if (max_value - min_value
                        > data.plot_options.orders_of_mag):
                    min_value = (max_value
                                 - data.plot_options.orders_of_mag)
                min_value = 10.0 ** min_value
                max_value = 10.0 ** max_value
            else:
                to_plot = Intensity
                min_value = to_plot.min() 
                max_value = to_plot.max()

                # Cut top and bottom of data as specified in cut variables
                min_value = min_value + (max_value-min_value)*cut_min
                max_value = max_value*cut_max

            # Check the size of the array to be plotted
            # print(to_plot.shape)

            # Set the axis (might be switched?)
            x_axis_mult = data.plot_options.x_limit_multiplier
            y_axis_mult = data.plot_options.y_limit_multiplier

            X = np.linspace(data.metadata.limits[0]*x_axis_mult,
                            data.metadata.limits[1]*x_axis_mult,
                            data.metadata.dimension[0]+1)
            Y = np.linspace(data.metadata.limits[2]*y_axis_mult,
                            data.metadata.limits[3]*y_axis_mult,
                            data.metadata.dimension[1]+1)

            # Create a meshgrid for both x and y
            x, y = np.meshgrid(X, Y)

            # Generate information on necessary colorrange
            levels = MaxNLocator(nbins=150).tick_values(min_value,
                                                        max_value)

            # Select colormap
            cmap = plt.get_cmap('hot')
            norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)

            # Create the figure
            fig, (ax0) = plt.subplots()

            # Plot the data on the meshgrids
            if data.plot_options.log:
                color_norm = matplotlib.colors.LogNorm(vmin=min_value,
                                                       vmax=max_value)
                im = ax0.pcolormesh(x, y, to_plot,
                                    cmap=cmap, norm=color_norm)
            else:
                im = ax0.pcolormesh(x, y, to_plot, cmap=cmap, norm=norm)

            # Add the colorbar
            cb = fig.colorbar(im, ax=ax0)
            cb.formatter.set_powerlimits((0, 0)) # Xu: for shorter scientific notation
            cb.ax.yaxis.set_offset_position('right') 

            # Add a title
            ax0.set_title(data.metadata.title, fontsize=10)

            # Add axis labels
            plt.xlabel(data.metadata.xlabel)
            plt.ylabel(data.metadata.ylabel)

            if data.plot_options.custom_ylim_top:
                ax0.set_ylim(top=data.plot_options.top_lim)

            if data.plot_options.custom_ylim_bottom:
                ax0.set_ylim(bottom=data.plot_options.bottom_lim)

            if data.plot_options.custom_xlim_left:
                ax0.set_xlim(left=data.plot_options.left_lim)

            if data.plot_options.custom_xlim_right:
                ax0.set_xlim(right=data.plot_options.right_lim)
            figs.append(fig)
            axs.append(ax0)
        else:
            print("Error, dimension not read correctly")

        plt.show()
    if len(figs)==1:
        return figs[0], axs[0]
    else:
        return figs, axs

class make_plot:
    """
    make_plot plots contents of McStasData objects
    Plotting is controlled through options assosciated with the
    McStasData objects.
    If a list is given, the plots appear individually.
    """

    def __init__(self, data_list, **kwargs):
        """
        plots McStasData, single object or list of McStasData
        The options concerning plotting are stored with the data
        Parameters
        ----------
        data_list : McStasData or list of McStasData
            McStasData to be plotted
        """

        # Relevant options:
        #  select colormap
        #  show / hide colorbar
        #  custom title / label
        #  color of 1d plot
        #  overlay several 1d
        #  log scale (orders of magnitude)
        #  compare several 1d
        #  compare 2D

        if isinstance(data_list, McStasData):
            # Only a single element, put it in a list for easier syntax later
            data_list = [data_list]

        number_of_plots = len(data_list)

        if "fontsize" in kwargs:
            plt.rcParams.update({'font.size': kwargs["fontsize"]})

        print("number of elements in data list = " + str(len(data_list)))

        index = -1
        for data in data_list:
            index = index + 1

            print("Plotting data with name " + data.metadata.component_name)
            if type(data.metadata.dimension) == int:
                fig, (ax0) = plt.subplots()

                x_axis_mult = data.plot_options.x_limit_multiplier
                #print(data.__dict__)
                x = data.xaxis*x_axis_mult
                y = data.Intensity
                y_err = data.Error

                plt.errorbar(x, y, yerr=y_err)

                if data.plot_options.log:
                    ax0.set_yscale("log", nonposy='clip')

                ax0.set_xlim(data.metadata.limits[0]*x_axis_mult,
                             data.metadata.limits[1]*x_axis_mult)

                # Add a title
                plt.title(data.metadata.title, fontsize=10)

                # Add axis labels
                plt.xlabel(data.metadata.xlabel)
                plt.ylabel(data.metadata.ylabel)

                if data.plot_options.custom_xlim_left:
                    ax0.set_xlim(left=data.plot_options.left_lim)

                if data.plot_options.custom_xlim_right:
                    ax0.set_xlim(right=data.plot_options.right_lim)
                plt.show()
            elif len(data.metadata.dimension) == 2:
                # Split the data into intensity, error and ncount
                Intensity = data.Intensity
                Error = data.Error
                Ncount = data.Ncount

                cut_max = data.plot_options.cut_max  # Default 1
                cut_min = data.plot_options.cut_min  # Default 0

                if data.plot_options.log:
                    to_plot = Intensity

                    max_data_value = to_plot.max()

                    min_value = np.min(Intensity[np.nonzero(Intensity)])
                    min_value = np.log10(min_value
                                         + (max_data_value-min_value)*cut_min)

                    max_value = np.log10(max_data_value*cut_max)

                    if (max_value - min_value
                            > data.plot_options.orders_of_mag):
                        min_value = (max_value
                                     - data.plot_options.orders_of_mag)
                    min_value = 10.0 ** min_value
                    max_value = 10.0 ** max_value
                else:
                    to_plot = Intensity
                    min_value = to_plot.min() 
                    max_value = to_plot.max()

                    # Cut top and bottom of data as specified in cut variables
                    min_value = min_value + (max_value-min_value)*cut_min
                    max_value = max_value*cut_max

                # Check the size of the array to be plotted
                # print(to_plot.shape)

                # Set the axis (might be switched?)
                x_axis_mult = data.plot_options.x_limit_multiplier
                y_axis_mult = data.plot_options.y_limit_multiplier

                X = np.linspace(data.metadata.limits[0]*x_axis_mult,
                                data.metadata.limits[1]*x_axis_mult,
                                data.metadata.dimension[0]+1)
                Y = np.linspace(data.metadata.limits[2]*y_axis_mult,
                                data.metadata.limits[3]*y_axis_mult,
                                data.metadata.dimension[1]+1)

                # Create a meshgrid for both x and y
                x, y = np.meshgrid(X, Y)

                # Generate information on necessary colorrange
                levels = MaxNLocator(nbins=150).tick_values(min_value,
                                                            max_value)

                # Select colormap
                cmap = plt.get_cmap('hot')
                norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)

                # Create the figure
                fig, (ax0) = plt.subplots()

                # Plot the data on the meshgrids
                if data.plot_options.log:
                    color_norm = matplotlib.colors.LogNorm(vmin=min_value,
                                                           vmax=max_value)
                    im = ax0.pcolormesh(x, y, to_plot,
                                        cmap=cmap, norm=color_norm)
                else:
                    im = ax0.pcolormesh(x, y, to_plot, cmap=cmap, norm=norm)

                # Add the colorbar
                cb = fig.colorbar(im, ax=ax0)
                cb.formatter.set_powerlimits((0, 0)) # Xu: for shorter scientific notation
                cb.ax.yaxis.set_offset_position('right') 

                # Add a title
                ax0.set_title(data.metadata.title, fontsize=10)
                
                # Add axis labels
                plt.xlabel(data.metadata.xlabel)
                plt.ylabel(data.metadata.ylabel)

                if data.plot_options.custom_ylim_top:
                    ax0.set_ylim(top=data.plot_options.top_lim)

                if data.plot_options.custom_ylim_bottom:
                    ax0.set_ylim(bottom=data.plot_options.bottom_lim)

                if data.plot_options.custom_xlim_left:
                    ax0.set_xlim(left=data.plot_options.left_lim)

                if data.plot_options.custom_xlim_right:
                    ax0.set_xlim(right=data.plot_options.right_lim)
                plt.show()
            else:
                print("Error, dimension not read correctly")
                
            plt.show()
        


class make_sub_plot:
    """
    make_plot plots contents of McStasData objects
    Plotting is controlled through options assosciated with the
    McStasData objects.  If a list is given, the plots appear in one
    subplot.
    """

    def __init__(self, data_list, **kwargs):
        """
        plots McStasData, single object or list of McStasData
        The options concerning plotting are stored with the data
        Parameters
        ----------
        data_list : McStasData or list of McStasData
            McStasData to be plotted
        """
        if not isinstance(data_list, McStasData):
            print("number of elements in data list = "
                  + str(len(data_list)))
        else:
            # Make list from single element to simplify syntax
            data_list = [data_list]

        number_of_plots = len(data_list)

        # Relevant options:
        #  select colormap
        #  show / hide colorbar
        #  custom title / label
        #  color of 1d plot
        #  overlay several 1d
        #  log scale (o$rders of magnitude)
        #  compare several 1d
        #  compare 2D

        # Find reasonable grid size for the number of plots
        dim2 = math.ceil(math.sqrt(number_of_plots))
        dim1 = math.ceil(number_of_plots/dim2)

        if "fontsize" in kwargs:
            plt.rcParams.update({'font.size': kwargs["fontsize"]})

        fig, axs = plt.subplots(dim1, dim2, figsize=(13, 7),gridspec_kw={'hspace':1,'wspace':1}) # add by Xu: hspace:0.5
        axs = np.array(axs)
        ax = axs.reshape(-1)

        index = -1
        for data in data_list:
            index = index + 1
            ax0 = ax[index]

            print("Plotting data with name "
                  + data.metadata.component_name)

            if isinstance(data.metadata.dimension, int):
                # fig = plt.figure(0)
                # plt.subplot(dim1, dim2, n_plot)
                x_axis_mult = data.plot_options.x_limit_multiplier

                x = data.xaxis*x_axis_mult
                y = data.Intensity
                y_err = data.Error

                ax0.errorbar(x, y, yerr=y_err)

                if data.plot_options.log:
                    ax0.set_yscale("log", nonposy='clip')

                ax0.set_xlim(data.metadata.limits[0]*x_axis_mult,
                             data.metadata.limits[1]*x_axis_mult)

                # Add a title
                ax0.set_title(data.metadata.title, fontsize=10)

                # Add axis labels
                ax0.set_xlabel(data.metadata.xlabel)
                ax0.set_ylabel(data.metadata.ylabel)

                if data.plot_options.custom_xlim_left:
                    ax0.set_xlim(left=data.plot_options.left_lim)

                if data.plot_options.custom_xlim_right:
                    ax0.set_xlim(right=data.plot_options.right_lim)

            elif len(data.metadata.dimension) == 2:

                # Split the data into intensity, error and ncount
                Intensity = data.Intensity
                Error = data.Error
                Ncount = data.Ncount

                cut_max = data.plot_options.cut_max  # Default 1
                cut_min = data.plot_options.cut_min  # Default 0

                if data.plot_options.log:
                    to_plot = Intensity

                    max_data_value = to_plot.max()

                    min_value = np.min(Intensity[np.nonzero(Intensity)])
                    min_value = np.log10(min_value
                                         + (max_data_value-min_value)*cut_min)

                    max_value = np.log10(max_data_value*cut_max)

                    if (max_value - min_value
                            > data.plot_options.orders_of_mag):
                        min_value = (max_value
                                     - data.plot_options.orders_of_mag)
                    min_value = 10.0 ** min_value
                    max_value = 10.0 ** max_value
                else:
                    to_plot = Intensity
                    min_value = to_plot.min() 
                    max_value = to_plot.max()

                    # Cut top and bottom of data as specified in cut variables
                    min_value = min_value + (max_value-min_value)*cut_min
                    max_value = max_value*cut_max

                # Check the size of the array to be plotted
                # print(to_plot.shape)

                # Set the axis
                x_axis_mult = data.plot_options.x_limit_multiplier
                y_axis_mult = data.plot_options.y_limit_multiplier

                X = np.linspace(data.metadata.limits[0]*x_axis_mult,
                                data.metadata.limits[1]*x_axis_mult,
                                data.metadata.dimension[0]+1)
                Y = np.linspace(data.metadata.limits[2]*y_axis_mult,
                                data.metadata.limits[3]*y_axis_mult,
                                data.metadata.dimension[1]+1)

                # Create a meshgrid for both x and y
                x, y = np.meshgrid(X, Y)

                # Generate information on necessary colorrange
                levels = MaxNLocator(nbins=150).tick_values(min_value,
                                                            max_value)

                # Select colormap
                cmap = plt.get_cmap(data.plot_options.colormap)

                # Select the colorscale normalization
                if data.plot_options.log:
                    norm = matplotlib.colors.LogNorm(vmin=min_value,
                                                     vmax=max_value)
                else:
                    norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)

                # Create plot
                im = ax0.pcolormesh(x, y, to_plot, cmap=cmap, norm=norm)

                def fmt(x, pos):
                    a, b = '{:.2e}'.format(x).split('e')
                    b = int(b)
                    if abs(float(a) - 1) < 0.01 :
                        return r'$10^{{{}}}$'.format(b)
                    else:
                        return r'${} \times 10^{{{}}}$'.format(a, b)

                # Add the colorbar
                if data.plot_options.colormap:
                    #cb = fig.colorbar(im, ax=ax0, format=matplotlib.ticker.FuncFormatter(fmt))
                    cb = fig.colorbar(im, ax=ax0)
                    cb.formatter.set_powerlimits((0, 0)) # Xu: for shorter scientific notation
                    cb.ax.yaxis.set_offset_position('right') 

                # Add a title
                ax0.set_title(data.metadata.title, fontsize=10)

                # Add axis labels
                ax0.set_xlabel(data.metadata.xlabel)
                ax0.set_ylabel(data.metadata.ylabel)

                if data.plot_options.custom_ylim_top:
                    ax0.set_ylim(top=data.plot_options.top_lim)

                if data.plot_options.custom_ylim_bottom:
                    ax0.set_ylim(bottom=data.plot_options.bottom_lim)

                if data.plot_options.custom_xlim_left:
                    ax0.set_xlim(left=data.plot_options.left_lim)

                if data.plot_options.custom_xlim_right:
                    ax0.set_xlim(right=data.plot_options.right_lim)

            else:
                print("Error, dimension not read correctly")

            plt.show()


class make_animation:
    """
    make_plot plots contents of McStasData objects
    Plotting is controlled through options assosciated with the
    McStasData objects.  If a list is given, the plots appear in one
    subplot.
    """

    def __init__(self, data_list, **kwargs):
        """
        plots McStasData, single object or list of McStasData
        The options concerning plotting are stored with the data
        Parameters
        ----------
        data_list : McStasData or list of McStasData
            McStasData to be plotted
        """
        if not isinstance(data_list, McStasData):
            print("number of elements in data list = "
                  + str(len(data_list)))
        else:
            # Make list from single element to simplify syntax
            data_list = [data_list]

        # Relevant options:
        #  select colormap
        #  show / hide colorbar
        #  custom title / label
        #  color of 1d plot
        #  overlay several 1d
        #  log scale (o$rders of magnitude)
        #  compare several 1d
        #  compare 2D

        if "fontsize" in kwargs:
            plt.rcParams.update({'font.size': kwargs["fontsize"]})
            
        if "fps" in kwargs:
            period_in_ms = 1000/kwargs["fps"]
        else:
            period_in_ms = 200

        fig = plt.figure()
        ax = plt.axes()
        #fig, ax = plt.subplot()
        
        # find limits for entire dataset
        maximum_values = []
        minimum_values = []
        
        is_1D = False
        is_2D = False
        
        for data in data_list:
            if isinstance(data.metadata.dimension, int):
                is_1D = True
                
                y = data.Intensity[np.nonzero(data.Intensity)]
                if len(y) > 0:
                    maximum_values.append(y.max())
                    minimum_values.append(y.min())
            
            elif len(data.metadata.dimension) == 2:
                is_2D = True
                
                y = data.Intensity[np.nonzero(data.Intensity)]
                if len(y) > 0:
                    maximum_values.append(y.max())
                    minimum_values.append(y.min())
        
        if len(maximum_values) > 0:
            maximum_value = np.array(maximum_values).max()
        else:
            maximum_value = 0
            
        if len(minimum_values) > 0:
            minimum_value = np.array(minimum_values).min()
        else:
            minimum_value = 0
        
        if is_1D and is_2D:
            raise InputError(
                "Both 1D and 2D data in animation, only one allowed.")

        # initialize plots
        
        data = data_list[0]
        if isinstance(data.metadata.dimension, int):
            x_axis_mult = data.plot_options.x_limit_multiplier
            
            x = data.xaxis*x_axis_mult
            y = data.Intensity
            y_err = data.Error
            
            er = ax.errorbar(x, y, yerr=y_err)
            
            if data.plot_options.log:
                    ax.set_yscale("log", nonposy='clip')

            ax.set_xlim(data.metadata.limits[0]*x_axis_mult,
                             data.metadata.limits[1]*x_axis_mult)

            # Add a title
            ax.set_title(data.metadata.title, fontsize=10)

            # Add axis labels
            ax.set_xlabel(data.metadata.xlabel)
            ax.set_ylabel(data.metadata.ylabel)

            if data.plot_options.custom_xlim_left:
                ax.set_xlim(left=data.plot_options.left_lim)

            if data.plot_options.custom_xlim_right:
                ax.set_xlim(right=data.plot_options.right_lim)
                
            ax.set_ylim(minimum_value, maximum_value)
        
        elif len(data.metadata.dimension) == 2:
            # Split the data into intensity, error and ncount
            Intensity = data.Intensity
            Error = data.Error
            Ncount = data.Ncount
            
            cut_max = data.plot_options.cut_max  # Default 1
            cut_min = data.plot_options.cut_min  # Default 0

            if data.plot_options.log:
                
                min_value = minimum_value
                max_value = maximum_value
                
                min_value = np.log10(min_value
                                     + (max_value-min_value)*cut_min)
                
                max_value = np.log10(max_value*cut_max)

                if (max_value - min_value
                        > data.plot_options.orders_of_mag):
                    min_value = (max_value
                                 - data.plot_options.orders_of_mag)
                    
                min_value = 10.0 ** min_value
                max_value = 10.0 ** max_value
            else:
                
                min_value = minimum_value 
                max_value = maximum_value

            # Check the size of the array to be plotted
            # print(to_plot.shape)

            # Set the axis
            x_axis_mult = data.plot_options.x_limit_multiplier
            y_axis_mult = data.plot_options.y_limit_multiplier

            X = np.linspace(data.metadata.limits[0]*x_axis_mult,
                            data.metadata.limits[1]*x_axis_mult,
                            data.metadata.dimension[0]+1)
            Y = np.linspace(data.metadata.limits[2]*y_axis_mult,
                            data.metadata.limits[3]*y_axis_mult,
                            data.metadata.dimension[1]+1)

            # Create a meshgrid for both x and y
            x, y = np.meshgrid(X, Y)

            # Generate information on necessary colorrange
            levels = MaxNLocator(nbins=150).tick_values(min_value,
                                                        max_value)

            # Select colormap
            cmap = plt.get_cmap(data.plot_options.colormap)

            # Select the colorscale normalization
            if data.plot_options.log:
                norm = matplotlib.colors.LogNorm(vmin=min_value,
                                                 vmax=max_value)
            else:
                norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)

            # Create plot
            im = ax.pcolormesh(x, y, Intensity,
                               cmap=cmap, norm=norm)

            def fmt(x, pos):
                a, b = '{:.2e}'.format(x).split('e')
                b = int(b)
                if abs(float(a) - 1) < 0.01 :
                    return r'$10^{{{}}}$'.format(b)
                else:
                    return r'${} \times 10^{{{}}}$'.format(a, b)

            # Add the colorbar
            if data.plot_options.colormap:
                #cb = fig.colorbar(im, ax=ax,format=matplotlib.ticker.FuncFormatter(fmt))
                cb = fig.colorbar(im, ax=ax)
                cb.formatter.set_powerlimits((0, 0)) # Xu: for shorter scientific notation
                cb.ax.yaxis.set_offset_position('right') 

            # Add a title
            ax.set_title(data.metadata.title, fontsize=10)

            # Add axis labels
            ax.set_xlabel(data.metadata.xlabel)
            ax.set_ylabel(data.metadata.ylabel)

            if data.plot_options.custom_ylim_top:
                ax.set_ylim(top=data.plot_options.top_lim)

            if data.plot_options.custom_ylim_bottom:
                ax.set_ylim(bottom=data.plot_options.bottom_lim)

            if data.plot_options.custom_xlim_left:
                ax.set_xlim(left=data.plot_options.left_lim)

            if data.plot_options.custom_xlim_right:
                ax.set_xlim(right=data.plot_options.right_lim)

        def init_1D():
            # initialize function for animation
            er.set_data([], [], []) # wont work
            return er,
        
        def animate_1D(index):
            data = data_list[index]
            intensity = data.Intensity
            error = data.Error
            
            er.set_data(x, intensity, error)
            return er,

        def init_2D():
            # initialize function for animation
            im.set_array([])
            return im,
            
        def animate_2D(index):
            data = data_list[index]
            intensity = data.Intensity

            im.set_array(intensity.ravel())
            return im,
        
        anim = animation.FuncAnimation(fig, animate_2D, #init_func=init_2D,
                                       frames=len(data_list),
                                       interval=period_in_ms,
                                       blit=False, repeat=True)

        #plt.draw()
        plt.show()

        # The animation doesn't play unless it is saved. Bug.
        if "filename" in kwargs:
            filename = kwargs["filename"]
            if not filename.endswith(".gif"):
                filename = filename + ".gif"

            # check if imagemagick available?
            print("Saving animation with filename : \"" + filename + "\"")
            anim.save(filename, writer="imagemagick")

# %% [markdown]
# ## FWHM vs lamda

# %%
import numpy as np
lam = np.linspace(0.1, 10, 100, endpoint=True)
ki = 2*np.pi/lam
def fwhm(ki, a, b, c=0):
    a+ b*ki+ c*ki**2
    
fwhm_h = np.genfromtxt(r'D:\5_Instrument\Mira_Bender_ref_tran/k_fwhm_h.dat',delimiter=',')    
fwhm_v = np.genfromtxt(r'D:\5_Instrument\Mira_Bender_ref_tran/k_fwhm_v.dat',delimiter=',')  

fwhm_h_lam = fwhm_h.copy()
fwhm_v_lam = fwhm_v.copy()

fwhm_h_lam[:,0] = 2*np.pi/fwhm_h[:,0]
fwhm_v_lam[:,0] = 2*np.pi/fwhm_v[:,0]

#np.savetxt(r'D:\5_Instrument\Mira_Bender_ref_tran/lam_fwhm_h.dat',fwhm_h[-1::-1,:])
#np.savetxt(r'D:\5_Instrument\Mira_Bender_ref_tran/lam_fwhm_v.dat',fwhm_v[-1::-1,:])
print(fwhm_h)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,4))
plt.plot(fwhm_h_lam[:,0],fwhm_h_lam[:,1],label='div_H')
plt.plot(fwhm_v_lam[:,0],fwhm_v_lam[:,1],label='div_V')
plt.xlabel(r'$\lambda$ ($\mathrm{\AA}$)')
plt.ylabel(r'Divergence (degree)')

plt.axvspan(6.18/3, 6.18/0.99, color='g', alpha=0.3, lw=0)
plt.text(4,2.5,'Data')
plt.text(8,2.5,'Extraplatation')
plt.legend()
plt.show()

plt.figure(figsize=(5,4))
plt.plot(fwhm_h[:,0],fwhm_h[:,1],label='div_H')
plt.plot(fwhm_v[:,0],fwhm_v[:,1],label='div_V')
plt.xlabel(r'$K_\mathrm{i}$ ($\mathrm{\AA}^{-1}$)')
plt.ylabel(r'Divergence (degree)')
plt.legend()
plt.show()

# %%
plt.close('all')
